# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

from cs231n.classifiers import LinearSVM

for regularization_strength in regularization_strengths:
    for learning_rate in learning_rates:
        svm = LinearSVM()        
        print("lr ", learning_rate, " reg ", regularization_strength)
        
        loss_hist = svm.train(X_train_feats, y_train, learning_rate=learning_rate, reg=regularization_strength,
                            num_iters=3000, verbose=True)
        
        y_train_pred = svm.predict(X_train_feats)
        training_accuracy = np.mean(y_train == y_train_pred)
        print('training accuracy: %f' % training_accuracy, )

        y_val_pred = svm.predict(X_val_feats)
        validation_accuracy = np.mean(y_val == y_val_pred)
        print('validation accuracy: %f' % validation_accuracy, )
        results[(learning_rate, regularization_strength)] = (training_accuracy, validation_accuracy)

        if validation_accuracy > best_val:
            best_val = validation_accuracy
            best_svm = svm

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved: %f' % best_val)
# Out:
# lr  1e-09  reg  50000.0
# iteration 0 / 3000: loss 84.777668
# iteration 100 / 3000: loss 83.287326
# iteration 200 / 3000: loss 81.818502
# iteration 300 / 3000: loss 80.364949
# iteration 400 / 3000: loss 78.957968
# iteration 500 / 3000: loss 77.563555
# iteration 600 / 3000: loss 76.200584
# iteration 700 / 3000: loss 74.884256
# iteration 800 / 3000: loss 73.587570
# iteration 900 / 3000: loss 72.292823
# iteration 1000 / 3000: loss 71.046824
# iteration 1100 / 3000: loss 69.795096
# iteration 1200 / 3000: loss 68.615433
# iteration 1300 / 3000: loss 67.430719
# iteration 1400 / 3000: loss 66.271799
# iteration 1500 / 3000: loss 65.139536
# iteration 1600 / 3000: loss 64.027443
# iteration 1700 / 3000: loss 62.945839
# iteration 1800 / 3000: loss 61.866466
# iteration 1900 / 3000: loss 60.812722
# iteration 2000 / 3000: loss 59.802028
# iteration 2100 / 3000: loss 58.788785
# iteration 2200 / 3000: loss 57.809762
# iteration 2300 / 3000: loss 56.828766
# iteration 2400 / 3000: loss 55.902660
# iteration 2500 / 3000: loss 54.963381
# iteration 2600 / 3000: loss 54.043020
# iteration 2700 / 3000: loss 53.171210
# iteration 2800 / 3000: loss 52.280502
# iteration 2900 / 3000: loss 51.429422
# training accuracy: 0.086673
# validation accuracy: 0.102000
# lr  1e-08  reg  50000.0
# iteration 0 / 3000: loss 86.302423
# iteration 100 / 3000: loss 72.285615
# iteration 200 / 3000: loss 60.803607
# iteration 300 / 3000: loss 51.421076
# iteration 400 / 3000: loss 43.724081
# iteration 500 / 3000: loss 37.425557
# iteration 600 / 3000: loss 32.272716
# iteration 700 / 3000: loss 28.044761
# iteration 800 / 3000: loss 24.595959
# iteration 900 / 3000: loss 21.766507
# iteration 1000 / 3000: loss 19.451577
# iteration 1100 / 3000: loss 17.559480
# iteration 1200 / 3000: loss 16.003903
# iteration 1300 / 3000: loss 14.734956
# iteration 1400 / 3000: loss 13.696322
# iteration 1500 / 3000: loss 12.843013
# iteration 1600 / 3000: loss 12.141469
# iteration 1700 / 3000: loss 11.572688
# iteration 1800 / 3000: loss 11.107526
# iteration 1900 / 3000: loss 10.725525
# iteration 2000 / 3000: loss 10.411166
# iteration 2100 / 3000: loss 10.156216
# iteration 2200 / 3000: loss 9.947179
# iteration 2300 / 3000: loss 9.774669
# iteration 2400 / 3000: loss 9.632685
# iteration 2500 / 3000: loss 9.518099
# iteration 2600 / 3000: loss 9.424908
# iteration 2700 / 3000: loss 9.348261
# iteration 2800 / 3000: loss 9.283978
# iteration 2900 / 3000: loss 9.232618
# training accuracy: 0.096939
# validation accuracy: 0.096000
# lr  1e-07  reg  50000.0
# iteration 0 / 3000: loss 85.217804
# iteration 100 / 3000: loss 19.210776
# iteration 200 / 3000: loss 10.368554
# iteration 300 / 3000: loss 9.182097
# iteration 400 / 3000: loss 9.024228
# iteration 500 / 3000: loss 9.003026
# iteration 600 / 3000: loss 9.000034
# iteration 700 / 3000: loss 8.999674
# iteration 800 / 3000: loss 8.999692
# iteration 900 / 3000: loss 8.999636
# iteration 1000 / 3000: loss 8.999612
# iteration 1100 / 3000: loss 8.999641
# iteration 1200 / 3000: loss 8.999723
# iteration 1300 / 3000: loss 8.999706
# iteration 1400 / 3000: loss 8.999707
# iteration 1500 / 3000: loss 8.999662
# iteration 1600 / 3000: loss 8.999616
# iteration 1700 / 3000: loss 8.999708
# iteration 1800 / 3000: loss 8.999637
# iteration 1900 / 3000: loss 8.999594
# iteration 2000 / 3000: loss 8.999717
# iteration 2100 / 3000: loss 8.999692
# iteration 2200 / 3000: loss 8.999563
# iteration 2300 / 3000: loss 8.999541
# iteration 2400 / 3000: loss 8.999645
# iteration 2500 / 3000: loss 8.999610
# iteration 2600 / 3000: loss 8.999605
# iteration 2700 / 3000: loss 8.999582
# iteration 2800 / 3000: loss 8.999624
# iteration 2900 / 3000: loss 8.999618
# training accuracy: 0.418143
# validation accuracy: 0.419000
# lr  1e-09  reg  500000.0
# iteration 0 / 3000: loss 755.305305
# iteration 100 / 3000: loss 619.960755
# iteration 200 / 3000: loss 509.167902
# iteration 300 / 3000: loss 418.457537
# iteration 400 / 3000: loss 344.207975
# iteration 500 / 3000: loss 283.410557
# iteration 600 / 3000: loss 233.648373
# iteration 700 / 3000: loss 192.906784
# iteration 800 / 3000: loss 159.554913
# iteration 900 / 3000: loss 132.251934
# iteration 1000 / 3000: loss 109.899970
# iteration 1100 / 3000: loss 91.596823
# iteration 1200 / 3000: loss 76.621688
# iteration 1300 / 3000: loss 64.359280
# iteration 1400 / 3000: loss 54.317484
# iteration 1500 / 3000: loss 46.097396
# iteration 1600 / 3000: loss 39.371196
# iteration 1700 / 3000: loss 33.863646
# iteration 1800 / 3000: loss 29.355880
# iteration 1900 / 3000: loss 25.664539
# iteration 2000 / 3000: loss 22.643112
# iteration 2100 / 3000: loss 20.166750
# iteration 2200 / 3000: loss 18.142091
# iteration 2300 / 3000: loss 16.483240
# iteration 2400 / 3000: loss 15.126687
# iteration 2500 / 3000: loss 14.016318
# iteration 2600 / 3000: loss 13.107421
# iteration 2700 / 3000: loss 12.361183
# iteration 2800 / 3000: loss 11.751062
# iteration 2900 / 3000: loss 11.254147
# training accuracy: 0.120224
# validation accuracy: 0.112000
# lr  1e-08  reg  500000.0
# iteration 0 / 3000: loss 800.304705
# iteration 100 / 3000: loss 115.017783
# iteration 200 / 3000: loss 23.203604
# iteration 300 / 3000: loss 10.903164
# iteration 400 / 3000: loss 9.254908
# iteration 500 / 3000: loss 9.034092
# iteration 600 / 3000: loss 9.004564
# iteration 700 / 3000: loss 9.000579
# iteration 800 / 3000: loss 9.000044
# iteration 900 / 3000: loss 8.999977
# iteration 1000 / 3000: loss 8.999967
# iteration 1100 / 3000: loss 8.999960
# iteration 1200 / 3000: loss 8.999969
# iteration 1300 / 3000: loss 8.999968
# iteration 1400 / 3000: loss 8.999959
# iteration 1500 / 3000: loss 8.999968
# iteration 1600 / 3000: loss 8.999970
# iteration 1700 / 3000: loss 8.999965
# iteration 1800 / 3000: loss 8.999965
# iteration 1900 / 3000: loss 8.999970
# iteration 2000 / 3000: loss 8.999962
# iteration 2100 / 3000: loss 8.999962
# iteration 2200 / 3000: loss 8.999966
# iteration 2300 / 3000: loss 8.999966
# iteration 2400 / 3000: loss 8.999968
# iteration 2500 / 3000: loss 8.999965
# iteration 2600 / 3000: loss 8.999956
# iteration 2700 / 3000: loss 8.999956
# iteration 2800 / 3000: loss 8.999961
# iteration 2900 / 3000: loss 8.999969
# training accuracy: 0.413449
# validation accuracy: 0.401000
# lr  1e-07  reg  500000.0
# iteration 0 / 3000: loss 748.770112
# iteration 100 / 3000: loss 8.999973
# iteration 200 / 3000: loss 8.999971
# iteration 300 / 3000: loss 8.999962
# iteration 400 / 3000: loss 8.999965
# iteration 500 / 3000: loss 8.999956
# iteration 600 / 3000: loss 8.999974
# iteration 700 / 3000: loss 8.999966
# iteration 800 / 3000: loss 8.999961
# iteration 900 / 3000: loss 8.999969
# iteration 1000 / 3000: loss 8.999971
# iteration 1100 / 3000: loss 8.999971
# iteration 1200 / 3000: loss 8.999960
# iteration 1300 / 3000: loss 8.999964
# iteration 1400 / 3000: loss 8.999972
# iteration 1500 / 3000: loss 8.999966
# iteration 1600 / 3000: loss 8.999961
# iteration 1700 / 3000: loss 8.999961
# iteration 1800 / 3000: loss 8.999969
# iteration 1900 / 3000: loss 8.999964
# iteration 2000 / 3000: loss 8.999974
# iteration 2100 / 3000: loss 8.999960
# iteration 2200 / 3000: loss 8.999977
# iteration 2300 / 3000: loss 8.999967
# iteration 2400 / 3000: loss 8.999964
# iteration 2500 / 3000: loss 8.999967
# iteration 2600 / 3000: loss 8.999969
# iteration 2700 / 3000: loss 8.999970
# iteration 2800 / 3000: loss 8.999972
# iteration 2900 / 3000: loss 8.999972
# training accuracy: 0.400816
# validation accuracy: 0.379000
# lr  1e-09  reg  5000000.0
# iteration 0 / 3000: loss 7762.541805
# iteration 100 / 3000: loss 1047.812132
# iteration 200 / 3000: loss 148.181135
# iteration 300 / 3000: loss 27.647339
# iteration 400 / 3000: loss 11.498337
# iteration 500 / 3000: loss 9.334728
# iteration 600 / 3000: loss 9.044885
# iteration 700 / 3000: loss 9.006004
# iteration 800 / 3000: loss 9.000806
# iteration 900 / 3000: loss 9.000105
# iteration 1000 / 3000: loss 9.000011
# iteration 1100 / 3000: loss 8.999999
# iteration 1200 / 3000: loss 8.999997
# iteration 1300 / 3000: loss 8.999996
# iteration 1400 / 3000: loss 8.999997
# iteration 1500 / 3000: loss 8.999997
# iteration 1600 / 3000: loss 8.999996
# iteration 1700 / 3000: loss 8.999997
# iteration 1800 / 3000: loss 8.999996
# iteration 1900 / 3000: loss 8.999997
# iteration 2000 / 3000: loss 8.999996
# iteration 2100 / 3000: loss 8.999997
# iteration 2200 / 3000: loss 8.999995
# iteration 2300 / 3000: loss 8.999996
# iteration 2400 / 3000: loss 8.999996
# iteration 2500 / 3000: loss 8.999996
# iteration 2600 / 3000: loss 8.999996
# iteration 2700 / 3000: loss 8.999996
# iteration 2800 / 3000: loss 8.999996
# iteration 2900 / 3000: loss 8.999997
# training accuracy: 0.413939
# validation accuracy: 0.417000
# lr  1e-08  reg  5000000.0
# iteration 0 / 3000: loss 7331.847369
# iteration 100 / 3000: loss 9.000002
# iteration 200 / 3000: loss 8.999996
# iteration 300 / 3000: loss 8.999995
# iteration 400 / 3000: loss 8.999996
# iteration 500 / 3000: loss 8.999997
# iteration 600 / 3000: loss 8.999996
# iteration 700 / 3000: loss 8.999997
# iteration 800 / 3000: loss 8.999996
# iteration 900 / 3000: loss 8.999996
# iteration 1000 / 3000: loss 8.999997
# iteration 1100 / 3000: loss 8.999997
# iteration 1200 / 3000: loss 8.999997
# iteration 1300 / 3000: loss 8.999996
# iteration 1400 / 3000: loss 8.999996
# iteration 1500 / 3000: loss 8.999996
# iteration 1600 / 3000: loss 8.999997
# iteration 1700 / 3000: loss 8.999997
# iteration 1800 / 3000: loss 8.999997
# iteration 1900 / 3000: loss 8.999997
# iteration 2000 / 3000: loss 8.999996
# iteration 2100 / 3000: loss 8.999997
# iteration 2200 / 3000: loss 8.999997
# iteration 2300 / 3000: loss 8.999997
# iteration 2400 / 3000: loss 8.999997
# iteration 2500 / 3000: loss 8.999997
# iteration 2600 / 3000: loss 8.999997
# iteration 2700 / 3000: loss 8.999996
# iteration 2800 / 3000: loss 8.999997
# iteration 2900 / 3000: loss 8.999997
# training accuracy: 0.404837
# validation accuracy: 0.407000
# lr  1e-07  reg  5000000.0
# iteration 0 / 3000: loss 7784.656094
# iteration 100 / 3000: loss 8.999999
# iteration 200 / 3000: loss 9.000000
# iteration 300 / 3000: loss 9.000001
# iteration 400 / 3000: loss 9.000001
# iteration 500 / 3000: loss 8.999999
# iteration 600 / 3000: loss 8.999999
# iteration 700 / 3000: loss 9.000000
# iteration 800 / 3000: loss 9.000000
# iteration 900 / 3000: loss 9.000000
# iteration 1000 / 3000: loss 9.000000
# iteration 1100 / 3000: loss 9.000000
# iteration 1200 / 3000: loss 9.000000
# iteration 1300 / 3000: loss 9.000000
# iteration 1400 / 3000: loss 9.000000
# iteration 1500 / 3000: loss 9.000000
# iteration 1600 / 3000: loss 9.000000
# iteration 1700 / 3000: loss 9.000000
# iteration 1800 / 3000: loss 9.000000
# iteration 1900 / 3000: loss 9.000000
# iteration 2000 / 3000: loss 9.000000
# iteration 2100 / 3000: loss 9.000001
# iteration 2200 / 3000: loss 9.000001
# iteration 2300 / 3000: loss 9.000000
# iteration 2400 / 3000: loss 9.000000
# iteration 2500 / 3000: loss 8.999999
# iteration 2600 / 3000: loss 9.000000
# iteration 2700 / 3000: loss 9.000001
# iteration 2800 / 3000: loss 9.000000
# iteration 2900 / 3000: loss 9.000000
# training accuracy: 0.310347
# validation accuracy: 0.328000
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.086673 val accuracy: 0.102000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.120224 val accuracy: 0.112000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.413939 val accuracy: 0.417000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.096939 val accuracy: 0.096000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.413449 val accuracy: 0.401000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.404837 val accuracy: 0.407000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.418143 val accuracy: 0.419000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.400816 val accuracy: 0.379000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.310347 val accuracy: 0.328000
# best validation accuracy achieved: 0.419000

# %%
# Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.421

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$
# Not really

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

data = {
    'X_train': X_train_feats, 
    'y_train': y_train, 
    'X_val': X_val_feats, 
    'y_val': y_val, 
    'X_test': X_test_feats, 
    'y_test': y_test, 
}

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****


learning_rates = np.logspace(-1, 0, num=6)
# regularization_strengths = np.logspace(-3, -1.5, num=6)
# learning_rates = np.linspace(0.0015, 0.002, num=5)
regularization_strengths = np.linspace(0, 0.001, num=5)

results = {}
best_val = -1
best_solver = None
total_combinations = len(regularization_strengths) * len(learning_rates)
current_combination = 0
for regularization_strength in regularization_strengths:
    for learning_rate in learning_rates:
        current_combination += 1
        print(f"{current_combination}/{total_combinations}: Training with learning_rate: {learning_rate} and regularization_strength {regularization_strength}")
        net = TwoLayerNet(input_dim, hidden_dim, num_classes)
        net.reg = regularization_strength
        solver = Solver(net, data,
                        update_rule='sgd',
                        optim_config={
                            'learning_rate': learning_rate,
                        },
                        lr_decay=0.95,
                        num_epochs=5, batch_size=200,
                        print_every=100)
        solver.train()
        
        validation_accuracy = solver.val_acc_history[-1]
        results[(learning_rate, regularization_strength)] = (solver.train_acc_history[-1], validation_accuracy)

        if validation_accuracy > best_val:
            best_val = validation_accuracy
            best_net = net
            best_solver = solver

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)



# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# 1/30: Training with learning_rate: 0.1 and regularization_strength 0.0
# (Iteration 1 / 1225) loss: 2.302590
# (Epoch 0 / 5) train acc: 0.082000; val_acc: 0.120000
# (Iteration 101 / 1225) loss: 2.300809
# (Iteration 201 / 1225) loss: 2.289569
# (Epoch 1 / 5) train acc: 0.228000; val_acc: 0.209000
# (Iteration 301 / 1225) loss: 2.212097
# (Iteration 401 / 1225) loss: 2.194576
# (Epoch 2 / 5) train acc: 0.297000; val_acc: 0.307000
# (Iteration 501 / 1225) loss: 2.027058
# (Iteration 601 / 1225) loss: 2.001773
# (Iteration 701 / 1225) loss: 1.922676
# (Epoch 3 / 5) train acc: 0.347000; val_acc: 0.339000
# (Iteration 801 / 1225) loss: 1.798708
# (Iteration 901 / 1225) loss: 1.886124
# (Epoch 4 / 5) train acc: 0.391000; val_acc: 0.352000
# (Iteration 1001 / 1225) loss: 1.810309
# (Iteration 1101 / 1225) loss: 1.901515
# (Iteration 1201 / 1225) loss: 1.823029
# (Epoch 5 / 5) train acc: 0.356000; val_acc: 0.359000
# 2/30: Training with learning_rate: 0.15848931924611134 and regularization_strength 0.0
# (Iteration 1 / 1225) loss: 2.302575
# (Epoch 0 / 5) train acc: 0.149000; val_acc: 0.129000
# (Iteration 101 / 1225) loss: 2.165233
# (Iteration 201 / 1225) loss: 2.034642
# (Epoch 1 / 5) train acc: 0.320000; val_acc: 0.331000
# (Iteration 301 / 1225) loss: 1.982905
# (Iteration 401 / 1225) loss: 1.710012
# (Epoch 2 / 5) train acc: 0.407000; val_acc: 0.420000
# (Iteration 501 / 1225) loss: 1.742373
# (Iteration 601 / 1225) loss: 1.604272
# (Iteration 701 / 1225) loss: 1.709709
# (Epoch 3 / 5) train acc: 0.452000; val_acc: 0.459000
# (Iteration 801 / 1225) loss: 1.515277
# (Iteration 901 / 1225) loss: 1.520297
# (Epoch 4 / 5) train acc: 0.456000; val_acc: 0.474000
# (Iteration 1001 / 1225) loss: 1.555369
# (Iteration 1101 / 1225) loss: 1.327741
# (Iteration 1201 / 1225) loss: 1.268204
# (Epoch 5 / 5) train acc: 0.567000; val_acc: 0.529000
# 3/30: Training with learning_rate: 0.251188643150958 and regularization_strength 0.0
# (Iteration 1 / 1225) loss: 2.302591
# (Epoch 0 / 5) train acc: 0.098000; val_acc: 0.113000
# (Iteration 101 / 1225) loss: 2.265546
# (Iteration 201 / 1225) loss: 2.131359
# (Epoch 1 / 5) train acc: 0.201000; val_acc: 0.206000
# (Iteration 301 / 1225) loss: 2.129453
# (Iteration 401 / 1225) loss: 2.118823
# (Epoch 2 / 5) train acc: 0.281000; val_acc: 0.285000
# (Iteration 501 / 1225) loss: 2.018330
# (Iteration 601 / 1225) loss: 1.841101
# (Iteration 701 / 1225) loss: 1.913630
# (Epoch 3 / 5) train acc: 0.333000; val_acc: 0.329000
# (Iteration 801 / 1225) loss: 1.833779
# (Iteration 901 / 1225) loss: 1.996169
# (Epoch 4 / 5) train acc: 0.312000; val_acc: 0.322000
# (Iteration 1001 / 1225) loss: 2.003493
# (Iteration 1101 / 1225) loss: 1.894403
# (Iteration 1201 / 1225) loss: 1.933636
# (Epoch 5 / 5) train acc: 0.361000; val_acc: 0.346000
# 4/30: Training with learning_rate: 0.3981071705534973 and regularization_strength 0.0
# (Iteration 1 / 1225) loss: 2.302568
# (Epoch 0 / 5) train acc: 0.102000; val_acc: 0.119000
# (Iteration 101 / 1225) loss: 2.028505
# (Iteration 201 / 1225) loss: 2.112994
# (Epoch 1 / 5) train acc: 0.340000; val_acc: 0.362000
# (Iteration 301 / 1225) loss: 1.827054
# (Iteration 401 / 1225) loss: 1.787655
# (Epoch 2 / 5) train acc: 0.427000; val_acc: 0.452000
# (Iteration 501 / 1225) loss: 1.685471
# (Iteration 601 / 1225) loss: 1.669429
# (Iteration 701 / 1225) loss: 1.706099
# (Epoch 3 / 5) train acc: 0.487000; val_acc: 0.458000
# (Iteration 801 / 1225) loss: 1.657723
# (Iteration 901 / 1225) loss: 1.712909
# (Epoch 4 / 5) train acc: 0.512000; val_acc: 0.493000
# (Iteration 1001 / 1225) loss: 1.559192
# (Iteration 1101 / 1225) loss: 1.616222
# (Iteration 1201 / 1225) loss: 1.628956
# (Epoch 5 / 5) train acc: 0.522000; val_acc: 0.496000
# 5/30: Training with learning_rate: 0.6309573444801934 and regularization_strength 0.0
# (Iteration 1 / 1225) loss: 2.302588
# (Epoch 0 / 5) train acc: 0.102000; val_acc: 0.079000
# (Iteration 101 / 1225) loss: 2.302585
# (Iteration 201 / 1225) loss: 2.302585
# (Epoch 1 / 5) train acc: 0.103000; val_acc: 0.087000
# (Iteration 301 / 1225) loss: 2.302585
# (Iteration 401 / 1225) loss: 2.302585
# (Epoch 2 / 5) train acc: 0.101000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: 2.302585
# (Iteration 601 / 1225) loss: 2.302585
# (Iteration 701 / 1225) loss: 2.302585
# (Epoch 3 / 5) train acc: 0.102000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: 2.302585
# (Iteration 901 / 1225) loss: 2.302585
# (Epoch 4 / 5) train acc: 0.106000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: 2.302585
# (Iteration 1101 / 1225) loss: 2.302585
# (Iteration 1201 / 1225) loss: 2.302585
# (Epoch 5 / 5) train acc: 0.096000; val_acc: 0.087000
# 6/30: Training with learning_rate: 1.0 and regularization_strength 0.0
# (Iteration 1 / 1225) loss: 2.302580
# (Epoch 0 / 5) train acc: 0.086000; val_acc: 0.102000
# (Iteration 101 / 1225) loss: 2.204947
# (Iteration 201 / 1225) loss: 2.049612
# (Epoch 1 / 5) train acc: 0.310000; val_acc: 0.293000
# (Iteration 301 / 1225) loss: 1.980532
# (Iteration 401 / 1225) loss: 1.916970
# (Epoch 2 / 5) train acc: 0.372000; val_acc: 0.360000
# (Iteration 501 / 1225) loss: 1.856584
# (Iteration 601 / 1225) loss: 1.858221
# (Iteration 701 / 1225) loss: 1.736475
# (Epoch 3 / 5) train acc: 0.403000; val_acc: 0.394000
# (Iteration 801 / 1225) loss: 1.873949
# (Iteration 901 / 1225) loss: 1.771995
# (Epoch 4 / 5) train acc: 0.416000; val_acc: 0.399000
# (Iteration 1001 / 1225) loss: 1.756570
# (Iteration 1101 / 1225) loss: 1.690462
# (Iteration 1201 / 1225) loss: 1.577351
# (Epoch 5 / 5) train acc: 0.425000; val_acc: 0.401000
# 7/30: Training with learning_rate: 0.1 and regularization_strength 0.00025
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.098000; val_acc: 0.102000
# (Iteration 101 / 1225) loss: 2.300134
# (Iteration 201 / 1225) loss: 2.245073
# (Epoch 1 / 5) train acc: 0.175000; val_acc: 0.176000
# (Iteration 301 / 1225) loss: 2.148829
# (Iteration 401 / 1225) loss: 2.041749
# (Epoch 2 / 5) train acc: 0.350000; val_acc: 0.343000
# (Iteration 501 / 1225) loss: 1.824441
# (Iteration 601 / 1225) loss: 1.905784
# (Iteration 701 / 1225) loss: 1.899748
# (Epoch 3 / 5) train acc: 0.393000; val_acc: 0.352000
# (Iteration 801 / 1225) loss: 1.832670
# (Iteration 901 / 1225) loss: 1.822549
# (Epoch 4 / 5) train acc: 0.395000; val_acc: 0.350000
# (Iteration 1001 / 1225) loss: 1.818825
# (Iteration 1101 / 1225) loss: 1.901048
# (Iteration 1201 / 1225) loss: 1.895034
# (Epoch 5 / 5) train acc: 0.405000; val_acc: 0.359000
# 8/30: Training with learning_rate: 0.15848931924611134 and regularization_strength 0.00025
# (Iteration 1 / 1225) loss: 2.302608
# (Epoch 0 / 5) train acc: 0.100000; val_acc: 0.105000
# (Iteration 101 / 1225) loss: 2.297181
# (Iteration 201 / 1225) loss: 2.257651
# (Epoch 1 / 5) train acc: 0.152000; val_acc: 0.146000
# (Iteration 301 / 1225) loss: 2.236555
# (Iteration 401 / 1225) loss: 2.171620
# (Epoch 2 / 5) train acc: 0.231000; val_acc: 0.251000
# (Iteration 501 / 1225) loss: 2.170445
# (Iteration 601 / 1225) loss: 2.132916
# (Iteration 701 / 1225) loss: 2.047474
# (Epoch 3 / 5) train acc: 0.305000; val_acc: 0.300000
# (Iteration 801 / 1225) loss: 1.994517
# (Iteration 901 / 1225) loss: 2.050518
# (Epoch 4 / 5) train acc: 0.315000; val_acc: 0.292000
# (Iteration 1001 / 1225) loss: 1.836706
# (Iteration 1101 / 1225) loss: 1.940291
# (Iteration 1201 / 1225) loss: 2.134513
# (Epoch 5 / 5) train acc: 0.388000; val_acc: 0.322000
# 9/30: Training with learning_rate: 0.251188643150958 and regularization_strength 0.00025
# (Iteration 1 / 1225) loss: 2.302582
# (Epoch 0 / 5) train acc: 0.102000; val_acc: 0.087000
# (Iteration 101 / 1225) loss: 2.156201
# (Iteration 201 / 1225) loss: 2.205248
# (Epoch 1 / 5) train acc: 0.143000; val_acc: 0.148000
# (Iteration 301 / 1225) loss: 2.121955
# (Iteration 401 / 1225) loss: 2.069002
# (Epoch 2 / 5) train acc: 0.137000; val_acc: 0.147000
# (Iteration 501 / 1225) loss: 2.095388
# (Iteration 601 / 1225) loss: 1.988784
# (Iteration 701 / 1225) loss: 2.048448
# (Epoch 3 / 5) train acc: 0.220000; val_acc: 0.233000
# (Iteration 801 / 1225) loss: 1.937780
# (Iteration 901 / 1225) loss: 2.005044
# (Epoch 4 / 5) train acc: 0.229000; val_acc: 0.236000
# (Iteration 1001 / 1225) loss: 2.030857
# (Iteration 1101 / 1225) loss: 1.952159
# (Iteration 1201 / 1225) loss: 1.926385
# (Epoch 5 / 5) train acc: 0.245000; val_acc: 0.249000
# 10/30: Training with learning_rate: 0.3981071705534973 and regularization_strength 0.00025
# (Iteration 1 / 1225) loss: 2.302599
# (Epoch 0 / 5) train acc: 0.120000; val_acc: 0.107000
# (Iteration 101 / 1225) loss: 2.248082
# (Iteration 201 / 1225) loss: 2.205518
# (Epoch 1 / 5) train acc: 0.260000; val_acc: 0.229000
# (Iteration 301 / 1225) loss: 2.203116
# (Iteration 401 / 1225) loss: 2.070364
# (Epoch 2 / 5) train acc: 0.360000; val_acc: 0.351000
# (Iteration 501 / 1225) loss: 1.988917
# (Iteration 601 / 1225) loss: 1.888488
# (Iteration 701 / 1225) loss: 1.877518
# (Epoch 3 / 5) train acc: 0.389000; val_acc: 0.358000
# (Iteration 801 / 1225) loss: 1.788111
# (Iteration 901 / 1225) loss: 1.942010
# (Epoch 4 / 5) train acc: 0.377000; val_acc: 0.379000
# (Iteration 1001 / 1225) loss: 1.866766
# (Iteration 1101 / 1225) loss: 1.866299
# (Iteration 1201 / 1225) loss: 1.685024
# (Epoch 5 / 5) train acc: 0.410000; val_acc: 0.391000
# 11/30: Training with learning_rate: 0.6309573444801934 and regularization_strength 0.00025
# (Iteration 1 / 1225) loss: 2.302591
# (Epoch 0 / 5) train acc: 0.096000; val_acc: 0.078000
# (Iteration 101 / 1225) loss: 2.027976
# (Iteration 201 / 1225) loss: 1.996059
# (Epoch 1 / 5) train acc: 0.300000; val_acc: 0.268000
# (Iteration 301 / 1225) loss: 2.097761
# (Iteration 401 / 1225) loss: 2.007148
# (Epoch 2 / 5) train acc: 0.332000; val_acc: 0.285000
# (Iteration 501 / 1225) loss: 1.870481
# (Iteration 601 / 1225) loss: 1.855585
# (Iteration 701 / 1225) loss: 1.841480
# (Epoch 3 / 5) train acc: 0.377000; val_acc: 0.303000
# (Iteration 801 / 1225) loss: 1.809874
# (Iteration 901 / 1225) loss: 1.745160
# (Epoch 4 / 5) train acc: 0.384000; val_acc: 0.299000
# (Iteration 1001 / 1225) loss: 1.663013
# (Iteration 1101 / 1225) loss: 1.675644
# (Iteration 1201 / 1225) loss: 1.674486
# (Epoch 5 / 5) train acc: 0.380000; val_acc: 0.303000
# 12/30: Training with learning_rate: 1.0 and regularization_strength 0.00025
# (Iteration 1 / 1225) loss: 2.302588
# (Epoch 0 / 5) train acc: 0.103000; val_acc: 0.087000
# (Iteration 101 / 1225) loss: 2.186815
# (Iteration 201 / 1225) loss: 1.997866
# (Epoch 1 / 5) train acc: 0.316000; val_acc: 0.325000
# (Iteration 301 / 1225) loss: 1.831455
# (Iteration 401 / 1225) loss: 1.749490
# (Epoch 2 / 5) train acc: 0.449000; val_acc: 0.421000
# (Iteration 501 / 1225) loss: 1.752873
# (Iteration 601 / 1225) loss: 1.792089
# (Iteration 701 / 1225) loss: 1.680145
# (Epoch 3 / 5) train acc: 0.432000; val_acc: 0.435000
# (Iteration 801 / 1225) loss: 1.618127
# (Iteration 901 / 1225) loss: 1.653530
# (Epoch 4 / 5) train acc: 0.428000; val_acc: 0.447000
# (Iteration 1001 / 1225) loss: 1.668119
# (Iteration 1101 / 1225) loss: 1.614291
# (Iteration 1201 / 1225) loss: 1.572860
# (Epoch 5 / 5) train acc: 0.459000; val_acc: 0.428000
# 13/30: Training with learning_rate: 0.1 and regularization_strength 0.0005
# (Iteration 1 / 1225) loss: 2.302600
# (Epoch 0 / 5) train acc: 0.098000; val_acc: 0.078000
# (Iteration 101 / 1225) loss: 2.302214
# (Iteration 201 / 1225) loss: 2.242989
# (Epoch 1 / 5) train acc: 0.137000; val_acc: 0.151000
# (Iteration 301 / 1225) loss: 2.238906
# (Iteration 401 / 1225) loss: 2.163599
# (Epoch 2 / 5) train acc: 0.248000; val_acc: 0.273000
# (Iteration 501 / 1225) loss: 2.057645
# (Iteration 601 / 1225) loss: 2.008364
# (Iteration 701 / 1225) loss: 1.940572
# (Epoch 3 / 5) train acc: 0.289000; val_acc: 0.309000
# (Iteration 801 / 1225) loss: 2.015079
# (Iteration 901 / 1225) loss: 2.050994
# (Epoch 4 / 5) train acc: 0.316000; val_acc: 0.312000
# (Iteration 1001 / 1225) loss: 2.000616
# (Iteration 1101 / 1225) loss: 2.029874
# (Iteration 1201 / 1225) loss: 1.935161
# (Epoch 5 / 5) train acc: 0.334000; val_acc: 0.329000
# 14/30: Training with learning_rate: 0.15848931924611134 and regularization_strength 0.0005
# (Iteration 1 / 1225) loss: 2.302622
# (Epoch 0 / 5) train acc: 0.114000; val_acc: 0.102000
# (Iteration 101 / 1225) loss: 2.297548
# (Iteration 201 / 1225) loss: 2.276044
# (Epoch 1 / 5) train acc: 0.162000; val_acc: 0.161000
# (Iteration 301 / 1225) loss: 2.243891
# (Iteration 401 / 1225) loss: 2.198585
# (Epoch 2 / 5) train acc: 0.168000; val_acc: 0.175000
# (Iteration 501 / 1225) loss: 2.197850
# (Iteration 601 / 1225) loss: 2.225198
# (Iteration 701 / 1225) loss: 2.174460
# (Epoch 3 / 5) train acc: 0.248000; val_acc: 0.230000
# (Iteration 801 / 1225) loss: 2.142614
# (Iteration 901 / 1225) loss: 2.094582
# (Epoch 4 / 5) train acc: 0.295000; val_acc: 0.283000
# (Iteration 1001 / 1225) loss: 2.084222
# (Iteration 1101 / 1225) loss: 2.044608
# (Iteration 1201 / 1225) loss: 2.061419
# (Epoch 5 / 5) train acc: 0.276000; val_acc: 0.287000
# 15/30: Training with learning_rate: 0.251188643150958 and regularization_strength 0.0005
# (Iteration 1 / 1225) loss: 2.302613
# (Epoch 0 / 5) train acc: 0.108000; val_acc: 0.082000
# (Iteration 101 / 1225) loss: 2.287062
# (Iteration 201 / 1225) loss: 2.170672
# (Epoch 1 / 5) train acc: 0.185000; val_acc: 0.183000
# (Iteration 301 / 1225) loss: 2.140144
# (Iteration 401 / 1225) loss: 2.218392
# (Epoch 2 / 5) train acc: 0.191000; val_acc: 0.184000
# (Iteration 501 / 1225) loss: 2.139748
# (Iteration 601 / 1225) loss: 2.206633
# (Iteration 701 / 1225) loss: 2.154920
# (Epoch 3 / 5) train acc: 0.220000; val_acc: 0.187000
# (Iteration 801 / 1225) loss: 2.118893
# (Iteration 901 / 1225) loss: 2.152733
# (Epoch 4 / 5) train acc: 0.196000; val_acc: 0.200000
# (Iteration 1001 / 1225) loss: 2.186609
# (Iteration 1101 / 1225) loss: 2.224375
# (Iteration 1201 / 1225) loss: 2.127424
# (Epoch 5 / 5) train acc: 0.219000; val_acc: 0.212000
# 16/30: Training with learning_rate: 0.3981071705534973 and regularization_strength 0.0005
# (Iteration 1 / 1225) loss: 2.302612
# (Epoch 0 / 5) train acc: 0.109000; val_acc: 0.087000
# (Iteration 101 / 1225) loss: 2.302605
# (Iteration 201 / 1225) loss: 2.302604
# (Epoch 1 / 5) train acc: 0.115000; val_acc: 0.087000
# (Iteration 301 / 1225) loss: 2.302603
# (Iteration 401 / 1225) loss: 2.302603
# (Epoch 2 / 5) train acc: 0.103000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: 2.302602
# (Iteration 601 / 1225) loss: 2.302601
# (Iteration 701 / 1225) loss: 2.302601
# (Epoch 3 / 5) train acc: 0.123000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: 2.302600
# (Iteration 901 / 1225) loss: 2.302600
# (Epoch 4 / 5) train acc: 0.099000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: 2.302599
# (Iteration 1101 / 1225) loss: 2.302599
# (Iteration 1201 / 1225) loss: 2.302598
# (Epoch 5 / 5) train acc: 0.103000; val_acc: 0.087000
# 17/30: Training with learning_rate: 0.6309573444801934 and regularization_strength 0.0005
# (Iteration 1 / 1225) loss: 2.302612
# (Epoch 0 / 5) train acc: 0.105000; val_acc: 0.113000
# (Iteration 101 / 1225) loss: 2.025446
# (Iteration 201 / 1225) loss: 2.053055
# (Epoch 1 / 5) train acc: 0.316000; val_acc: 0.338000
# (Iteration 301 / 1225) loss: 1.886748
# (Iteration 401 / 1225) loss: 1.941419
# (Epoch 2 / 5) train acc: 0.292000; val_acc: 0.339000
# (Iteration 501 / 1225) loss: 1.886154
# (Iteration 601 / 1225) loss: 1.955362
# (Iteration 701 / 1225) loss: 1.755735
# (Epoch 3 / 5) train acc: 0.355000; val_acc: 0.353000
# (Iteration 801 / 1225) loss: 1.906800
# (Iteration 901 / 1225) loss: 1.828540
# (Epoch 4 / 5) train acc: 0.351000; val_acc: 0.355000
# (Iteration 1001 / 1225) loss: 1.868713
# (Iteration 1101 / 1225) loss: 1.848678
# (Iteration 1201 / 1225) loss: 1.838556
# (Epoch 5 / 5) train acc: 0.423000; val_acc: 0.429000
# 18/30: Training with learning_rate: 1.0 and regularization_strength 0.0005
# (Iteration 1 / 1225) loss: 2.302600
# (Epoch 0 / 5) train acc: 0.105000; val_acc: 0.105000
# (Iteration 101 / 1225) loss: 2.006366
# (Iteration 201 / 1225) loss: 2.172953
# (Epoch 1 / 5) train acc: 0.273000; val_acc: 0.299000
# (Iteration 301 / 1225) loss: 1.958358
# (Iteration 401 / 1225) loss: 2.057312
# (Epoch 2 / 5) train acc: 0.294000; val_acc: 0.306000
# (Iteration 501 / 1225) loss: 1.975083
# (Iteration 601 / 1225) loss: 1.934308
# (Iteration 701 / 1225) loss: 1.927470
# (Epoch 3 / 5) train acc: 0.337000; val_acc: 0.327000
# (Iteration 801 / 1225) loss: 2.036994
# (Iteration 901 / 1225) loss: 1.906035
# (Epoch 4 / 5) train acc: 0.341000; val_acc: 0.345000
# (Iteration 1001 / 1225) loss: 1.918222
# (Iteration 1101 / 1225) loss: 1.832588
# (Iteration 1201 / 1225) loss: 1.882395
# (Epoch 5 / 5) train acc: 0.323000; val_acc: 0.334000
# 19/30: Training with learning_rate: 0.1 and regularization_strength 0.00075
# (Iteration 1 / 1225) loss: 2.302618
# (Epoch 0 / 5) train acc: 0.109000; val_acc: 0.078000
# (Iteration 101 / 1225) loss: 2.302256
# (Iteration 201 / 1225) loss: 2.292291
# (Epoch 1 / 5) train acc: 0.140000; val_acc: 0.138000
# (Iteration 301 / 1225) loss: 2.251408
# (Iteration 401 / 1225) loss: 2.263884
# (Epoch 2 / 5) train acc: 0.154000; val_acc: 0.158000
# (Iteration 501 / 1225) loss: 2.262493
# (Iteration 601 / 1225) loss: 2.266458
# (Iteration 701 / 1225) loss: 2.215292
# (Epoch 3 / 5) train acc: 0.151000; val_acc: 0.160000
# (Iteration 801 / 1225) loss: 2.228089
# (Iteration 901 / 1225) loss: 2.238562
# (Epoch 4 / 5) train acc: 0.219000; val_acc: 0.196000
# (Iteration 1001 / 1225) loss: 2.202895
# (Iteration 1101 / 1225) loss: 2.141064
# (Iteration 1201 / 1225) loss: 2.146663
# (Epoch 5 / 5) train acc: 0.241000; val_acc: 0.264000
# 20/30: Training with learning_rate: 0.15848931924611134 and regularization_strength 0.00075
# (Iteration 1 / 1225) loss: 2.302628
# (Epoch 0 / 5) train acc: 0.090000; val_acc: 0.105000
# (Iteration 101 / 1225) loss: 2.301673
# (Iteration 201 / 1225) loss: 2.251078
# (Epoch 1 / 5) train acc: 0.168000; val_acc: 0.156000
# (Iteration 301 / 1225) loss: 2.207069
# (Iteration 401 / 1225) loss: 2.270193
# (Epoch 2 / 5) train acc: 0.178000; val_acc: 0.159000
# (Iteration 501 / 1225) loss: 2.251648
# (Iteration 601 / 1225) loss: 2.212105
# (Iteration 701 / 1225) loss: 2.130715
# (Epoch 3 / 5) train acc: 0.221000; val_acc: 0.220000
# (Iteration 801 / 1225) loss: 2.149165
# (Iteration 901 / 1225) loss: 2.183563
# (Epoch 4 / 5) train acc: 0.234000; val_acc: 0.254000
# (Iteration 1001 / 1225) loss: 2.117314
# (Iteration 1101 / 1225) loss: 2.013405
# (Iteration 1201 / 1225) loss: 2.128319
# (Epoch 5 / 5) train acc: 0.243000; val_acc: 0.261000
# 21/30: Training with learning_rate: 0.251188643150958 and regularization_strength 0.00075
# (Iteration 1 / 1225) loss: 2.302627
# (Epoch 0 / 5) train acc: 0.092000; val_acc: 0.087000
# (Iteration 101 / 1225) loss: 2.275107
# (Iteration 201 / 1225) loss: 2.200525
# (Epoch 1 / 5) train acc: 0.090000; val_acc: 0.087000
# (Iteration 301 / 1225) loss: 2.205105
# (Iteration 401 / 1225) loss: 2.194155
# (Epoch 2 / 5) train acc: 0.106000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: 2.222089
# (Iteration 601 / 1225) loss: 2.151001
# (Iteration 701 / 1225) loss: 2.235807
# (Epoch 3 / 5) train acc: 0.110000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: 2.234668
# (Iteration 901 / 1225) loss: 2.251947
# (Epoch 4 / 5) train acc: 0.109000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: 2.244502
# (Iteration 1101 / 1225) loss: 2.060503
# (Iteration 1201 / 1225) loss: 2.088772
# (Epoch 5 / 5) train acc: 0.168000; val_acc: 0.153000
# 22/30: Training with learning_rate: 0.3981071705534973 and regularization_strength 0.00075
# (Iteration 1 / 1225) loss: 2.302616
# (Epoch 0 / 5) train acc: 0.090000; val_acc: 0.113000
# (Iteration 101 / 1225) loss: 2.285124
# (Iteration 201 / 1225) loss: 2.097665
# (Epoch 1 / 5) train acc: 0.308000; val_acc: 0.340000
# (Iteration 301 / 1225) loss: 1.963752
# (Iteration 401 / 1225) loss: 1.975921
# (Epoch 2 / 5) train acc: 0.342000; val_acc: 0.358000
# (Iteration 501 / 1225) loss: 1.847960
# (Iteration 601 / 1225) loss: 1.954938
# (Iteration 701 / 1225) loss: 1.857286
# (Epoch 3 / 5) train acc: 0.378000; val_acc: 0.380000
# (Iteration 801 / 1225) loss: 1.948762
# (Iteration 901 / 1225) loss: 1.886329
# (Epoch 4 / 5) train acc: 0.377000; val_acc: 0.391000
# (Iteration 1001 / 1225) loss: 1.847407
# (Iteration 1101 / 1225) loss: 1.830460
# (Iteration 1201 / 1225) loss: 2.011571
# (Epoch 5 / 5) train acc: 0.396000; val_acc: 0.402000
# 23/30: Training with learning_rate: 0.6309573444801934 and regularization_strength 0.00075
# (Iteration 1 / 1225) loss: 2.302625
# (Epoch 0 / 5) train acc: 0.126000; val_acc: 0.153000
# (Iteration 101 / 1225) loss: 2.187722
# (Iteration 201 / 1225) loss: 2.234718
# (Epoch 1 / 5) train acc: 0.175000; val_acc: 0.158000
# (Iteration 301 / 1225) loss: 2.186001
# (Iteration 401 / 1225) loss: 2.212982
# (Epoch 2 / 5) train acc: 0.158000; val_acc: 0.166000
# (Iteration 501 / 1225) loss: 2.258541
# (Iteration 601 / 1225) loss: 2.169526
# (Iteration 701 / 1225) loss: 2.002410
# (Epoch 3 / 5) train acc: 0.324000; val_acc: 0.313000
# (Iteration 801 / 1225) loss: 1.939390
# (Iteration 901 / 1225) loss: 2.072483
# (Epoch 4 / 5) train acc: 0.303000; val_acc: 0.319000
# (Iteration 1001 / 1225) loss: 1.929672
# (Iteration 1101 / 1225) loss: 1.921174
# (Iteration 1201 / 1225) loss: 1.952158
# (Epoch 5 / 5) train acc: 0.338000; val_acc: 0.326000
# 24/30: Training with learning_rate: 1.0 and regularization_strength 0.00075
# (Iteration 1 / 1225) loss: 2.302617
# (Epoch 0 / 5) train acc: 0.102000; val_acc: 0.079000
# (Iteration 101 / 1225) loss: 2.302612
# (Iteration 201 / 1225) loss: 2.302609
# (Epoch 1 / 5) train acc: 0.091000; val_acc: 0.087000
# (Iteration 301 / 1225) loss: 2.302605
# (Iteration 401 / 1225) loss: 2.302603
# (Epoch 2 / 5) train acc: 0.092000; val_acc: 0.087000
# (Iteration 501 / 1225) loss: 2.302600
# (Iteration 601 / 1225) loss: 2.302598
# (Iteration 701 / 1225) loss: 2.302597
# (Epoch 3 / 5) train acc: 0.089000; val_acc: 0.087000
# (Iteration 801 / 1225) loss: 2.302595
# (Iteration 901 / 1225) loss: 2.302594
# (Epoch 4 / 5) train acc: 0.111000; val_acc: 0.087000
# (Iteration 1001 / 1225) loss: 2.302593
# (Iteration 1101 / 1225) loss: 2.302592
# (Iteration 1201 / 1225) loss: 2.302591
# (Epoch 5 / 5) train acc: 0.093000; val_acc: 0.087000
# 25/30: Training with learning_rate: 0.1 and regularization_strength 0.001
# (Iteration 1 / 1225) loss: 2.302617
# (Epoch 0 / 5) train acc: 0.099000; val_acc: 0.107000
# (Iteration 101 / 1225) loss: 2.297161
# (Iteration 201 / 1225) loss: 2.138453
# (Epoch 1 / 5) train acc: 0.234000; val_acc: 0.255000
# (Iteration 301 / 1225) loss: 2.220274
# (Iteration 401 / 1225) loss: 2.023498
# (Epoch 2 / 5) train acc: 0.331000; val_acc: 0.370000
# (Iteration 501 / 1225) loss: 1.916376
# (Iteration 601 / 1225) loss: 1.881887
# (Iteration 701 / 1225) loss: 1.881339
# (Epoch 3 / 5) train acc: 0.409000; val_acc: 0.426000
# (Iteration 801 / 1225) loss: 1.763434
# (Iteration 901 / 1225) loss: 1.683733
# (Epoch 4 / 5) train acc: 0.440000; val_acc: 0.447000
# (Iteration 1001 / 1225) loss: 1.754211
# (Iteration 1101 / 1225) loss: 1.697796
# (Iteration 1201 / 1225) loss: 1.792961
# (Epoch 5 / 5) train acc: 0.477000; val_acc: 0.460000
# 26/30: Training with learning_rate: 0.15848931924611134 and regularization_strength 0.001
# (Iteration 1 / 1225) loss: 2.302613
# (Epoch 0 / 5) train acc: 0.093000; val_acc: 0.105000
# (Iteration 101 / 1225) loss: 2.294727
# (Iteration 201 / 1225) loss: 2.166262
# (Epoch 1 / 5) train acc: 0.234000; val_acc: 0.227000
# (Iteration 301 / 1225) loss: 2.182048
# (Iteration 401 / 1225) loss: 2.189559
# (Epoch 2 / 5) train acc: 0.235000; val_acc: 0.249000
# (Iteration 501 / 1225) loss: 2.084462
# (Iteration 601 / 1225) loss: 2.082477
# (Iteration 701 / 1225) loss: 2.063396
# (Epoch 3 / 5) train acc: 0.344000; val_acc: 0.345000
# (Iteration 801 / 1225) loss: 1.981352
# (Iteration 901 / 1225) loss: 1.908783
# (Epoch 4 / 5) train acc: 0.381000; val_acc: 0.411000
# (Iteration 1001 / 1225) loss: 1.945887
# (Iteration 1101 / 1225) loss: 1.698602
# (Iteration 1201 / 1225) loss: 1.873857
# (Epoch 5 / 5) train acc: 0.392000; val_acc: 0.416000
# 27/30: Training with learning_rate: 0.251188643150958 and regularization_strength 0.001
# (Iteration 1 / 1225) loss: 2.302616
# (Epoch 0 / 5) train acc: 0.101000; val_acc: 0.105000
# (Iteration 101 / 1225) loss: 2.127854
# (Iteration 201 / 1225) loss: 1.952703
# (Epoch 1 / 5) train acc: 0.338000; val_acc: 0.326000
# (Iteration 301 / 1225) loss: 1.922546
# (Iteration 401 / 1225) loss: 1.900123
# (Epoch 2 / 5) train acc: 0.331000; val_acc: 0.320000
# (Iteration 501 / 1225) loss: 1.949944
# (Iteration 601 / 1225) loss: 1.841459
# (Iteration 701 / 1225) loss: 1.918897
# (Epoch 3 / 5) train acc: 0.336000; val_acc: 0.321000
# (Iteration 801 / 1225) loss: 1.915863
# (Iteration 901 / 1225) loss: 1.931409
# (Epoch 4 / 5) train acc: 0.343000; val_acc: 0.316000
# (Iteration 1001 / 1225) loss: 1.916684
# (Iteration 1101 / 1225) loss: 1.811067
# (Iteration 1201 / 1225) loss: 1.936386
# (Epoch 5 / 5) train acc: 0.338000; val_acc: 0.324000
# 28/30: Training with learning_rate: 0.3981071705534973 and regularization_strength 0.001
# (Iteration 1 / 1225) loss: 2.302630
# (Epoch 0 / 5) train acc: 0.099000; val_acc: 0.119000
# (Iteration 101 / 1225) loss: 2.106134
# (Iteration 201 / 1225) loss: 2.021405
# (Epoch 1 / 5) train acc: 0.262000; val_acc: 0.273000
# (Iteration 301 / 1225) loss: 2.106304
# (Iteration 401 / 1225) loss: 2.068517
# (Epoch 2 / 5) train acc: 0.256000; val_acc: 0.286000
# (Iteration 501 / 1225) loss: 2.114931
# (Iteration 601 / 1225) loss: 1.924456
# (Iteration 701 / 1225) loss: 1.925001
# (Epoch 3 / 5) train acc: 0.317000; val_acc: 0.346000
# (Iteration 801 / 1225) loss: 1.997010
# (Iteration 901 / 1225) loss: 1.898912
# (Epoch 4 / 5) train acc: 0.324000; val_acc: 0.362000
# (Iteration 1001 / 1225) loss: 1.922229
# (Iteration 1101 / 1225) loss: 1.937866
# (Iteration 1201 / 1225) loss: 1.897161
# (Epoch 5 / 5) train acc: 0.400000; val_acc: 0.373000
# 29/30: Training with learning_rate: 0.6309573444801934 and regularization_strength 0.001
# (Iteration 1 / 1225) loss: 2.302617
# (Epoch 0 / 5) train acc: 0.104000; val_acc: 0.119000
# (Iteration 101 / 1225) loss: 1.868502
# (Iteration 201 / 1225) loss: 1.853044
# (Epoch 1 / 5) train acc: 0.375000; val_acc: 0.386000
# (Iteration 301 / 1225) loss: 2.058069
# (Iteration 401 / 1225) loss: 1.955602
# (Epoch 2 / 5) train acc: 0.388000; val_acc: 0.400000
# (Iteration 501 / 1225) loss: 1.746287
# (Iteration 601 / 1225) loss: 1.749433
# (Iteration 701 / 1225) loss: 1.757531
# (Epoch 3 / 5) train acc: 0.492000; val_acc: 0.433000
# (Iteration 801 / 1225) loss: 1.658940
# (Iteration 901 / 1225) loss: 1.622695
# (Epoch 4 / 5) train acc: 0.474000; val_acc: 0.441000
# (Iteration 1001 / 1225) loss: 1.550159
# (Iteration 1101 / 1225) loss: 1.481205
# (Iteration 1201 / 1225) loss: 1.506357
# (Epoch 5 / 5) train acc: 0.542000; val_acc: 0.496000
# 30/30: Training with learning_rate: 1.0 and regularization_strength 0.001
# (Iteration 1 / 1225) loss: 2.302637
# (Epoch 0 / 5) train acc: 0.100000; val_acc: 0.079000
# (Iteration 101 / 1225) loss: 2.021110
# (Iteration 201 / 1225) loss: 1.810224
# (Epoch 1 / 5) train acc: 0.310000; val_acc: 0.318000
# (Iteration 301 / 1225) loss: 1.875444
# (Iteration 401 / 1225) loss: 1.837466
# (Epoch 2 / 5) train acc: 0.350000; val_acc: 0.355000
# (Iteration 501 / 1225) loss: 1.887768
# (Iteration 601 / 1225) loss: 1.939444
# (Iteration 701 / 1225) loss: 1.939540
# (Epoch 3 / 5) train acc: 0.361000; val_acc: 0.344000
# (Iteration 801 / 1225) loss: 1.873492
# (Iteration 901 / 1225) loss: 1.822519
# (Epoch 4 / 5) train acc: 0.360000; val_acc: 0.349000
# (Iteration 1001 / 1225) loss: 1.863054
# (Iteration 1101 / 1225) loss: 1.685227
# (Iteration 1201 / 1225) loss: 1.774291
# (Epoch 5 / 5) train acc: 0.365000; val_acc: 0.351000
# lr 1.000000e-01 reg 0.000000e+00 train accuracy: 0.356000 val accuracy: 0.359000
# lr 1.000000e-01 reg 2.500000e-04 train accuracy: 0.405000 val accuracy: 0.359000
# lr 1.000000e-01 reg 5.000000e-04 train accuracy: 0.334000 val accuracy: 0.329000
# lr 1.000000e-01 reg 7.500000e-04 train accuracy: 0.241000 val accuracy: 0.264000
# lr 1.000000e-01 reg 1.000000e-03 train accuracy: 0.477000 val accuracy: 0.460000
# lr 1.584893e-01 reg 0.000000e+00 train accuracy: 0.567000 val accuracy: 0.529000
# lr 1.584893e-01 reg 2.500000e-04 train accuracy: 0.388000 val accuracy: 0.322000
# lr 1.584893e-01 reg 5.000000e-04 train accuracy: 0.276000 val accuracy: 0.287000
# lr 1.584893e-01 reg 7.500000e-04 train accuracy: 0.243000 val accuracy: 0.261000
# lr 1.584893e-01 reg 1.000000e-03 train accuracy: 0.392000 val accuracy: 0.416000
# lr 2.511886e-01 reg 0.000000e+00 train accuracy: 0.361000 val accuracy: 0.346000
# lr 2.511886e-01 reg 2.500000e-04 train accuracy: 0.245000 val accuracy: 0.249000
# lr 2.511886e-01 reg 5.000000e-04 train accuracy: 0.219000 val accuracy: 0.212000
# lr 2.511886e-01 reg 7.500000e-04 train accuracy: 0.168000 val accuracy: 0.153000
# lr 2.511886e-01 reg 1.000000e-03 train accuracy: 0.338000 val accuracy: 0.324000
# lr 3.981072e-01 reg 0.000000e+00 train accuracy: 0.522000 val accuracy: 0.496000
# lr 3.981072e-01 reg 2.500000e-04 train accuracy: 0.410000 val accuracy: 0.391000
# lr 3.981072e-01 reg 5.000000e-04 train accuracy: 0.103000 val accuracy: 0.087000
# lr 3.981072e-01 reg 7.500000e-04 train accuracy: 0.396000 val accuracy: 0.402000
# lr 3.981072e-01 reg 1.000000e-03 train accuracy: 0.400000 val accuracy: 0.373000
# lr 6.309573e-01 reg 0.000000e+00 train accuracy: 0.096000 val accuracy: 0.087000
# lr 6.309573e-01 reg 2.500000e-04 train accuracy: 0.380000 val accuracy: 0.303000
# lr 6.309573e-01 reg 5.000000e-04 train accuracy: 0.423000 val accuracy: 0.429000
# lr 6.309573e-01 reg 7.500000e-04 train accuracy: 0.338000 val accuracy: 0.326000
# lr 6.309573e-01 reg 1.000000e-03 train accuracy: 0.542000 val accuracy: 0.496000
# lr 1.000000e+00 reg 0.000000e+00 train accuracy: 0.425000 val accuracy: 0.401000
# lr 1.000000e+00 reg 2.500000e-04 train accuracy: 0.459000 val accuracy: 0.428000
# lr 1.000000e+00 reg 5.000000e-04 train accuracy: 0.323000 val accuracy: 0.334000
# lr 1.000000e+00 reg 7.500000e-04 train accuracy: 0.093000 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.000000e-03 train accuracy: 0.365000 val accuracy: 0.351000
# best validation accuracy achieved during cross-validation: 0.529000

# %%
# Visualize the cross-validation results
import math
import pdb

# pdb.set_trace()

# x_scatter = [math.log10(x[0]) for x in results]
# y_scatter = [math.log10(x[1]) for x in results]

# # plot training accuracy
# marker_size = 100
# colors = [results[x][0] for x in results]
# plt.subplot(2, 1, 1)
# plt.tight_layout(pad=3)
# plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
# plt.colorbar()
# plt.xlabel('log learning rate')
# plt.ylabel('log regularization strength')
# plt.title('CIFAR-10 training accuracy')

# # plot validation accuracy
# colors = [results[x][1] for x in results] # default size of markers is 20
# plt.subplot(2, 1, 2)
# plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
# plt.colorbar()
# plt.xlabel('log learning rate')
# plt.ylabel('log regularization strength')
# plt.title('CIFAR-10 validation accuracy')
# plt.show()


x_scatter = [(x[0]) for x in results]
y_scatter = [(x[1]) for x in results]
# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.tight_layout(pad=3)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('learning rate')
plt.ylabel('regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('learning rate')
plt.ylabel('regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.531

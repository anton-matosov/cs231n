# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 30 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

from cs231n.classifiers import LinearSVM

for regularization_strength in regularization_strengths:
    for learning_rate in learning_rates:
        svm = LinearSVM()        
        print("lr ", learning_rate, " reg ", regularization_strength)
        
        loss_hist = svm.train(X_train_feats, y_train, learning_rate=learning_rate, reg=regularization_strength,
                            num_iters=3000, verbose=True)
        
        y_train_pred = svm.predict(X_train_feats)
        training_accuracy = np.mean(y_train == y_train_pred)
        print('training accuracy: %f' % training_accuracy, )

        y_val_pred = svm.predict(X_val_feats)
        validation_accuracy = np.mean(y_val == y_val_pred)
        print('validation accuracy: %f' % validation_accuracy, )
        results[(learning_rate, regularization_strength)] = (training_accuracy, validation_accuracy)

        if validation_accuracy > best_val:
            best_val = validation_accuracy
            best_svm = svm

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved: %f' % best_val)
# Out:
# lr  1e-09  reg  50000.0
# iteration 0 / 3000: loss 95.924752
# iteration 100 / 3000: loss 94.203120
# iteration 200 / 3000: loss 92.515244
# iteration 300 / 3000: loss 90.849839
# iteration 400 / 3000: loss 89.221833
# iteration 500 / 3000: loss 87.646884
# iteration 600 / 3000: loss 86.088907
# iteration 700 / 3000: loss 84.577979
# iteration 800 / 3000: loss 83.068063
# iteration 900 / 3000: loss 81.607093
# iteration 1000 / 3000: loss 80.169506
# iteration 1100 / 3000: loss 78.763392
# iteration 1200 / 3000: loss 77.372174
# iteration 1300 / 3000: loss 76.023512
# iteration 1400 / 3000: loss 74.686613
# iteration 1500 / 3000: loss 73.394281
# iteration 1600 / 3000: loss 72.118881
# iteration 1700 / 3000: loss 70.878692
# iteration 1800 / 3000: loss 69.647516
# iteration 1900 / 3000: loss 68.442542
# iteration 2000 / 3000: loss 67.256638
# iteration 2100 / 3000: loss 66.095763
# iteration 2200 / 3000: loss 64.978327
# iteration 2300 / 3000: loss 63.872057
# iteration 2400 / 3000: loss 62.785520
# iteration 2500 / 3000: loss 61.714391
# iteration 2600 / 3000: loss 60.679334
# iteration 2700 / 3000: loss 59.650299
# iteration 2800 / 3000: loss 58.654274
# iteration 2900 / 3000: loss 57.668823
# training accuracy: 0.088837
# validation accuracy: 0.094000
# lr  1e-08  reg  50000.0
# iteration 0 / 3000: loss 100.683977
# iteration 100 / 3000: loss 84.060114
# iteration 200 / 3000: loss 70.447863
# iteration 300 / 3000: loss 59.305617
# iteration 400 / 3000: loss 50.180413
# iteration 500 / 3000: loss 42.716404
# iteration 600 / 3000: loss 36.598778
# iteration 700 / 3000: loss 31.598239
# iteration 800 / 3000: loss 27.502353
# iteration 900 / 3000: loss 24.153772
# iteration 1000 / 3000: loss 21.400201
# iteration 1100 / 3000: loss 19.146540
# iteration 1200 / 3000: loss 17.310241
# iteration 1300 / 3000: loss 15.805104
# iteration 1400 / 3000: loss 14.568318
# iteration 1500 / 3000: loss 13.560066
# iteration 1600 / 3000: loss 12.731471
# iteration 1700 / 3000: loss 12.055163
# iteration 1800 / 3000: loss 11.500611
# iteration 1900 / 3000: loss 11.045235
# iteration 2000 / 3000: loss 10.675223
# iteration 2100 / 3000: loss 10.372171
# iteration 2200 / 3000: loss 10.125230
# iteration 2300 / 3000: loss 9.919852
# iteration 2400 / 3000: loss 9.752162
# iteration 2500 / 3000: loss 9.617074
# iteration 2600 / 3000: loss 9.504390
# iteration 2700 / 3000: loss 9.412759
# iteration 2800 / 3000: loss 9.338599
# iteration 2900 / 3000: loss 9.275848
# training accuracy: 0.126388
# validation accuracy: 0.131000
# lr  1e-07  reg  50000.0
# iteration 0 / 3000: loss 97.737185
# iteration 100 / 3000: loss 20.883809
# iteration 200 / 3000: loss 10.590262
# iteration 300 / 3000: loss 9.213038
# iteration 400 / 3000: loss 9.028205
# iteration 500 / 3000: loss 9.003489
# iteration 600 / 3000: loss 9.000177
# iteration 700 / 3000: loss 8.999643
# iteration 800 / 3000: loss 8.999696
# iteration 900 / 3000: loss 8.999666
# iteration 1000 / 3000: loss 8.999621
# iteration 1100 / 3000: loss 8.999655
# iteration 1200 / 3000: loss 8.999641
# iteration 1300 / 3000: loss 8.999695
# iteration 1400 / 3000: loss 8.999683
# iteration 1500 / 3000: loss 8.999638
# iteration 1600 / 3000: loss 8.999660
# iteration 1700 / 3000: loss 8.999642
# iteration 1800 / 3000: loss 8.999568
# iteration 1900 / 3000: loss 8.999644
# iteration 2000 / 3000: loss 8.999655
# iteration 2100 / 3000: loss 8.999645
# iteration 2200 / 3000: loss 8.999535
# iteration 2300 / 3000: loss 8.999616
# iteration 2400 / 3000: loss 8.999590
# iteration 2500 / 3000: loss 8.999614
# iteration 2600 / 3000: loss 8.999598
# iteration 2700 / 3000: loss 8.999601
# iteration 2800 / 3000: loss 8.999599
# iteration 2900 / 3000: loss 8.999602
# training accuracy: 0.422265
# validation accuracy: 0.428000
# lr  1e-09  reg  500000.0
# iteration 0 / 3000: loss 872.008154
# iteration 100 / 3000: loss 715.496947
# iteration 200 / 3000: loss 587.370158
# iteration 300 / 3000: loss 482.504206
# iteration 400 / 3000: loss 396.627446
# iteration 500 / 3000: loss 326.322833
# iteration 600 / 3000: loss 268.779371
# iteration 700 / 3000: loss 221.675939
# iteration 800 / 3000: loss 183.101934
# iteration 900 / 3000: loss 151.526690
# iteration 1000 / 3000: loss 125.676077
# iteration 1100 / 3000: loss 104.520384
# iteration 1200 / 3000: loss 87.197520
# iteration 1300 / 3000: loss 73.012038
# iteration 1400 / 3000: loss 61.405929
# iteration 1500 / 3000: loss 51.904159
# iteration 1600 / 3000: loss 44.119763
# iteration 1700 / 3000: loss 37.752763
# iteration 1800 / 3000: loss 32.537373
# iteration 1900 / 3000: loss 28.269050
# iteration 2000 / 3000: loss 24.773862
# iteration 2100 / 3000: loss 21.916316
# iteration 2200 / 3000: loss 19.573652
# iteration 2300 / 3000: loss 17.656357
# iteration 2400 / 3000: loss 16.086086
# iteration 2500 / 3000: loss 14.799687
# iteration 2600 / 3000: loss 13.748878
# iteration 2700 / 3000: loss 12.886832
# iteration 2800 / 3000: loss 12.183215
# iteration 2900 / 3000: loss 11.604870
# training accuracy: 0.084000
# validation accuracy: 0.081000
# lr  1e-08  reg  500000.0
# iteration 0 / 3000: loss 908.757172
# iteration 100 / 3000: loss 129.549347
# iteration 200 / 3000: loss 25.153151
# iteration 300 / 3000: loss 11.164105
# iteration 400 / 3000: loss 9.289986
# iteration 500 / 3000: loss 9.038799
# iteration 600 / 3000: loss 9.005157
# iteration 700 / 3000: loss 9.000664
# iteration 800 / 3000: loss 9.000065
# iteration 900 / 3000: loss 8.999976
# iteration 1000 / 3000: loss 8.999965
# iteration 1100 / 3000: loss 8.999970
# iteration 1200 / 3000: loss 8.999966
# iteration 1300 / 3000: loss 8.999956
# iteration 1400 / 3000: loss 8.999969
# iteration 1500 / 3000: loss 8.999965
# iteration 1600 / 3000: loss 8.999960
# iteration 1700 / 3000: loss 8.999966
# iteration 1800 / 3000: loss 8.999956
# iteration 1900 / 3000: loss 8.999960
# iteration 2000 / 3000: loss 8.999970
# iteration 2100 / 3000: loss 8.999965
# iteration 2200 / 3000: loss 8.999959
# iteration 2300 / 3000: loss 8.999956
# iteration 2400 / 3000: loss 8.999957
# iteration 2500 / 3000: loss 8.999962
# iteration 2600 / 3000: loss 8.999959
# iteration 2700 / 3000: loss 8.999968
# iteration 2800 / 3000: loss 8.999956
# iteration 2900 / 3000: loss 8.999961
# training accuracy: 0.425265
# validation accuracy: 0.422000
# lr  1e-07  reg  500000.0
# iteration 0 / 3000: loss 863.415692
# iteration 100 / 3000: loss 8.999970
# iteration 200 / 3000: loss 8.999964
# iteration 300 / 3000: loss 8.999964
# iteration 400 / 3000: loss 8.999959
# iteration 500 / 3000: loss 8.999965
# iteration 600 / 3000: loss 8.999965
# iteration 700 / 3000: loss 8.999955
# iteration 800 / 3000: loss 8.999962
# iteration 900 / 3000: loss 8.999961
# iteration 1000 / 3000: loss 8.999971
# iteration 1100 / 3000: loss 8.999962
# iteration 1200 / 3000: loss 8.999959
# iteration 1300 / 3000: loss 8.999957
# iteration 1400 / 3000: loss 8.999962
# iteration 1500 / 3000: loss 8.999955
# iteration 1600 / 3000: loss 8.999967
# iteration 1700 / 3000: loss 8.999963
# iteration 1800 / 3000: loss 8.999966
# iteration 1900 / 3000: loss 8.999965
# iteration 2000 / 3000: loss 8.999963
# iteration 2100 / 3000: loss 8.999971
# iteration 2200 / 3000: loss 8.999969
# iteration 2300 / 3000: loss 8.999958
# iteration 2400 / 3000: loss 8.999965
# iteration 2500 / 3000: loss 8.999964
# iteration 2600 / 3000: loss 8.999963
# iteration 2700 / 3000: loss 8.999960
# iteration 2800 / 3000: loss 8.999971
# iteration 2900 / 3000: loss 8.999969
# training accuracy: 0.415571
# validation accuracy: 0.409000
# lr  1e-09  reg  5000000.0
# iteration 0 / 3000: loss 8567.547196
# iteration 100 / 3000: loss 1155.677694
# iteration 200 / 3000: loss 162.631831
# iteration 300 / 3000: loss 29.583482
# iteration 400 / 3000: loss 11.757806
# iteration 500 / 3000: loss 9.369363
# iteration 600 / 3000: loss 9.049506
# iteration 700 / 3000: loss 9.006617
# iteration 800 / 3000: loss 9.000887
# iteration 900 / 3000: loss 9.000116
# iteration 1000 / 3000: loss 9.000013
# iteration 1100 / 3000: loss 8.999998
# iteration 1200 / 3000: loss 8.999997
# iteration 1300 / 3000: loss 8.999996
# iteration 1400 / 3000: loss 8.999997
# iteration 1500 / 3000: loss 8.999996
# iteration 1600 / 3000: loss 8.999996
# iteration 1700 / 3000: loss 8.999997
# iteration 1800 / 3000: loss 8.999997
# iteration 1900 / 3000: loss 8.999996
# iteration 2000 / 3000: loss 8.999996
# iteration 2100 / 3000: loss 8.999997
# iteration 2200 / 3000: loss 8.999996
# iteration 2300 / 3000: loss 8.999996
# iteration 2400 / 3000: loss 8.999996
# iteration 2500 / 3000: loss 8.999996
# iteration 2600 / 3000: loss 8.999995
# iteration 2700 / 3000: loss 8.999996
# iteration 2800 / 3000: loss 8.999997
# iteration 2900 / 3000: loss 8.999996
# training accuracy: 0.422673
# validation accuracy: 0.417000
# lr  1e-08  reg  5000000.0
# iteration 0 / 3000: loss 8687.964192
# iteration 100 / 3000: loss 9.000003
# iteration 200 / 3000: loss 8.999996
# iteration 300 / 3000: loss 8.999997
# iteration 400 / 3000: loss 8.999996
# iteration 500 / 3000: loss 8.999997
# iteration 600 / 3000: loss 8.999997
# iteration 700 / 3000: loss 8.999997
# iteration 800 / 3000: loss 8.999997
# iteration 900 / 3000: loss 8.999996
# iteration 1000 / 3000: loss 8.999996
# iteration 1100 / 3000: loss 8.999996
# iteration 1200 / 3000: loss 8.999995
# iteration 1300 / 3000: loss 8.999996
# iteration 1400 / 3000: loss 8.999996
# iteration 1500 / 3000: loss 8.999997
# iteration 1600 / 3000: loss 8.999996
# iteration 1700 / 3000: loss 8.999996
# iteration 1800 / 3000: loss 8.999996
# iteration 1900 / 3000: loss 8.999997
# iteration 2000 / 3000: loss 8.999997
# iteration 2100 / 3000: loss 8.999996
# iteration 2200 / 3000: loss 8.999996
# iteration 2300 / 3000: loss 8.999996
# iteration 2400 / 3000: loss 8.999997
# iteration 2500 / 3000: loss 8.999997
# iteration 2600 / 3000: loss 8.999996
# iteration 2700 / 3000: loss 8.999996
# iteration 2800 / 3000: loss 8.999997
# iteration 2900 / 3000: loss 8.999996
# training accuracy: 0.421837
# validation accuracy: 0.430000
# lr  1e-07  reg  5000000.0
# iteration 0 / 3000: loss 8867.291583
# iteration 100 / 3000: loss 9.000000
# iteration 200 / 3000: loss 8.999999
# iteration 300 / 3000: loss 9.000000
# iteration 400 / 3000: loss 9.000000
# iteration 500 / 3000: loss 9.000000
# iteration 600 / 3000: loss 9.000001
# iteration 700 / 3000: loss 9.000000
# iteration 800 / 3000: loss 9.000000
# iteration 900 / 3000: loss 9.000000
# iteration 1000 / 3000: loss 9.000000
# iteration 1100 / 3000: loss 8.999999
# iteration 1200 / 3000: loss 9.000001
# iteration 1300 / 3000: loss 9.000001
# iteration 1400 / 3000: loss 9.000000
# iteration 1500 / 3000: loss 9.000001
# iteration 1600 / 3000: loss 9.000001
# iteration 1700 / 3000: loss 9.000001
# iteration 1800 / 3000: loss 8.999999
# iteration 1900 / 3000: loss 9.000000
# iteration 2000 / 3000: loss 8.999999
# iteration 2100 / 3000: loss 9.000000
# iteration 2200 / 3000: loss 8.999999
# iteration 2300 / 3000: loss 9.000000
# iteration 2400 / 3000: loss 8.999999
# iteration 2500 / 3000: loss 8.999999
# iteration 2600 / 3000: loss 9.000000
# iteration 2700 / 3000: loss 9.000002
# iteration 2800 / 3000: loss 8.999999
# iteration 2900 / 3000: loss 9.000000
# training accuracy: 0.305143
# validation accuracy: 0.296000
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.088837 val accuracy: 0.094000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.084000 val accuracy: 0.081000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.422673 val accuracy: 0.417000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.126388 val accuracy: 0.131000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.425265 val accuracy: 0.422000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.421837 val accuracy: 0.430000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.422265 val accuracy: 0.428000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.415571 val accuracy: 0.409000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.305143 val accuracy: 0.296000
# best validation accuracy achieved: 0.430000

# %%
# Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.414

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$
# Not really

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 175)
# (49000, 174)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

data = {
    'X_train': X_train_feats, 
    'y_train': y_train, 
    'X_val': X_val_feats, 
    'y_val': y_val, 
    'X_test': X_test_feats, 
    'y_test': y_test, 
}

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****


# learning_rates = np.logspace(-1, 0, num=6)
# regularization_strengths = np.logspace(-3, -1.5, num=6)
learning_rates = np.linspace(0.1, 0.15, num=5)
regularization_strengths = np.linspace(0., 0.01, num=5)

results = {}
best_val = -1
best_solver = None
total_combinations = len(regularization_strengths) * len(learning_rates)
current_combination = 0
for regularization_strength in regularization_strengths:
    for learning_rate in learning_rates:
        current_combination += 1
        print(f"{current_combination}/{total_combinations}: Training with learning_rate: {learning_rate} and regularization_strength {regularization_strength}")
        net = TwoLayerNet(input_dim, hidden_dim, num_classes)
        net.reg = regularization_strength
        solver = Solver(net, data,
                        update_rule='sgd',
                        optim_config={
                            'learning_rate': learning_rate,
                        },
                        lr_decay=0.95,
                        num_epochs=8, batch_size=200,
                        print_every=100)
        solver.train()
        
        validation_accuracy = solver.val_acc_history[-1]
        results[(learning_rate, regularization_strength)] = (solver.train_acc_history[-1], validation_accuracy)

        if validation_accuracy > best_val:
            best_val = validation_accuracy
            best_net = net
            best_solver = solver

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)



# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# 1/25: Training with learning_rate: 0.1 and regularization_strength 0.0
# (Iteration 1 / 1960) loss: 2.302587
# (Epoch 0 / 8) train acc: 0.099000; val_acc: 0.107000
# (Iteration 101 / 1960) loss: 2.295990
# (Iteration 201 / 1960) loss: 2.203988
# (Epoch 1 / 8) train acc: 0.252000; val_acc: 0.265000
# (Iteration 301 / 1960) loss: 2.191765
# (Iteration 401 / 1960) loss: 1.987924
# (Epoch 2 / 8) train acc: 0.358000; val_acc: 0.355000
# (Iteration 501 / 1960) loss: 1.927113
# (Iteration 601 / 1960) loss: 1.998388
# (Iteration 701 / 1960) loss: 1.916778
# (Epoch 3 / 8) train acc: 0.363000; val_acc: 0.376000
# (Iteration 801 / 1960) loss: 1.986255
# (Iteration 901 / 1960) loss: 1.890760
# (Epoch 4 / 8) train acc: 0.370000; val_acc: 0.384000
# (Iteration 1001 / 1960) loss: 1.943405
# (Iteration 1101 / 1960) loss: 1.866986
# (Iteration 1201 / 1960) loss: 1.713567
# (Epoch 5 / 8) train acc: 0.399000; val_acc: 0.416000
# (Iteration 1301 / 1960) loss: 1.815154
# (Iteration 1401 / 1960) loss: 1.769852
# (Epoch 6 / 8) train acc: 0.445000; val_acc: 0.434000
# (Iteration 1501 / 1960) loss: 1.780183
# (Iteration 1601 / 1960) loss: 1.615659
# (Iteration 1701 / 1960) loss: 1.740560
# (Epoch 7 / 8) train acc: 0.470000; val_acc: 0.434000
# (Iteration 1801 / 1960) loss: 1.831405
# (Iteration 1901 / 1960) loss: 1.650571
# (Epoch 8 / 8) train acc: 0.443000; val_acc: 0.431000
# 2/25: Training with learning_rate: 0.1125 and regularization_strength 0.0
# (Iteration 1 / 1960) loss: 2.302580
# (Epoch 0 / 8) train acc: 0.095000; val_acc: 0.107000
# (Iteration 101 / 1960) loss: 2.296181
# (Iteration 201 / 1960) loss: 2.096027
# (Epoch 1 / 8) train acc: 0.280000; val_acc: 0.296000
# (Iteration 301 / 1960) loss: 2.000687
# (Iteration 401 / 1960) loss: 1.810370
# (Epoch 2 / 8) train acc: 0.414000; val_acc: 0.437000
# (Iteration 501 / 1960) loss: 1.672483
# (Iteration 601 / 1960) loss: 1.702246
# (Iteration 701 / 1960) loss: 1.622267
# (Epoch 3 / 8) train acc: 0.460000; val_acc: 0.482000
# (Iteration 801 / 1960) loss: 1.531375
# (Iteration 901 / 1960) loss: 1.525902
# (Epoch 4 / 8) train acc: 0.494000; val_acc: 0.488000
# (Iteration 1001 / 1960) loss: 1.540423
# (Iteration 1101 / 1960) loss: 1.581821
# (Iteration 1201 / 1960) loss: 1.610557
# (Epoch 5 / 8) train acc: 0.462000; val_acc: 0.501000
# (Iteration 1301 / 1960) loss: 1.600452
# (Iteration 1401 / 1960) loss: 1.439580
# (Epoch 6 / 8) train acc: 0.490000; val_acc: 0.512000
# (Iteration 1501 / 1960) loss: 1.472641
# (Iteration 1601 / 1960) loss: 1.615327
# (Iteration 1701 / 1960) loss: 1.537726
# (Epoch 7 / 8) train acc: 0.504000; val_acc: 0.511000
# (Iteration 1801 / 1960) loss: 1.520039
# (Iteration 1901 / 1960) loss: 1.513772
# (Epoch 8 / 8) train acc: 0.521000; val_acc: 0.511000
# 3/25: Training with learning_rate: 0.125 and regularization_strength 0.0
# (Iteration 1 / 1960) loss: 2.302577
# (Epoch 0 / 8) train acc: 0.121000; val_acc: 0.110000
# (Iteration 101 / 1960) loss: 2.298776
# (Iteration 201 / 1960) loss: 2.217568
# (Epoch 1 / 8) train acc: 0.214000; val_acc: 0.204000
# (Iteration 301 / 1960) loss: 2.183091
# (Iteration 401 / 1960) loss: 2.116922
# (Epoch 2 / 8) train acc: 0.294000; val_acc: 0.300000
# (Iteration 501 / 1960) loss: 1.998523
# (Iteration 601 / 1960) loss: 1.914827
# (Iteration 701 / 1960) loss: 1.947003
# (Epoch 3 / 8) train acc: 0.340000; val_acc: 0.330000
# (Iteration 801 / 1960) loss: 1.967292
# (Iteration 901 / 1960) loss: 1.754223
# (Epoch 4 / 8) train acc: 0.328000; val_acc: 0.323000
# (Iteration 1001 / 1960) loss: 2.004316
# (Iteration 1101 / 1960) loss: 1.876985
# (Iteration 1201 / 1960) loss: 1.969767
# (Epoch 5 / 8) train acc: 0.322000; val_acc: 0.325000
# (Iteration 1301 / 1960) loss: 1.958915
# (Iteration 1401 / 1960) loss: 1.932387
# (Epoch 6 / 8) train acc: 0.342000; val_acc: 0.332000
# (Iteration 1501 / 1960) loss: 1.913765
# (Iteration 1601 / 1960) loss: 1.859159
# (Iteration 1701 / 1960) loss: 1.870278
# (Epoch 7 / 8) train acc: 0.338000; val_acc: 0.322000
# (Iteration 1801 / 1960) loss: 1.882430
# (Iteration 1901 / 1960) loss: 1.962675
# (Epoch 8 / 8) train acc: 0.335000; val_acc: 0.329000
# 4/25: Training with learning_rate: 0.1375 and regularization_strength 0.0
# (Iteration 1 / 1960) loss: 2.302584
# (Epoch 0 / 8) train acc: 0.106000; val_acc: 0.078000
# (Iteration 101 / 1960) loss: 2.232410
# (Iteration 201 / 1960) loss: 1.915031
# (Epoch 1 / 8) train acc: 0.335000; val_acc: 0.328000
# (Iteration 301 / 1960) loss: 1.822395
# (Iteration 401 / 1960) loss: 1.808970
# (Epoch 2 / 8) train acc: 0.398000; val_acc: 0.408000
# (Iteration 501 / 1960) loss: 1.705819
# (Iteration 601 / 1960) loss: 1.555724
# (Iteration 701 / 1960) loss: 1.563597
# (Epoch 3 / 8) train acc: 0.468000; val_acc: 0.464000
# (Iteration 801 / 1960) loss: 1.371138
# (Iteration 901 / 1960) loss: 1.358881
# (Epoch 4 / 8) train acc: 0.509000; val_acc: 0.475000
# (Iteration 1001 / 1960) loss: 1.441317
# (Iteration 1101 / 1960) loss: 1.461038
# (Iteration 1201 / 1960) loss: 1.262585
# (Epoch 5 / 8) train acc: 0.545000; val_acc: 0.521000
# (Iteration 1301 / 1960) loss: 1.256276
# (Iteration 1401 / 1960) loss: 1.211779
# (Epoch 6 / 8) train acc: 0.530000; val_acc: 0.536000
# (Iteration 1501 / 1960) loss: 1.275041
# (Iteration 1601 / 1960) loss: 1.247931
# (Iteration 1701 / 1960) loss: 1.305654
# (Epoch 7 / 8) train acc: 0.551000; val_acc: 0.547000
# (Iteration 1801 / 1960) loss: 1.245667
# (Iteration 1901 / 1960) loss: 1.231367
# (Epoch 8 / 8) train acc: 0.589000; val_acc: 0.559000
# 5/25: Training with learning_rate: 0.15 and regularization_strength 0.0
# (Iteration 1 / 1960) loss: 2.302555
# (Epoch 0 / 8) train acc: 0.135000; val_acc: 0.141000
# (Iteration 101 / 1960) loss: 2.280414
# (Iteration 201 / 1960) loss: 2.108294
# (Epoch 1 / 8) train acc: 0.209000; val_acc: 0.223000
# (Iteration 301 / 1960) loss: 2.115985
# (Iteration 401 / 1960) loss: 2.084056
# (Epoch 2 / 8) train acc: 0.210000; val_acc: 0.233000
# (Iteration 501 / 1960) loss: 2.000067
# (Iteration 601 / 1960) loss: 1.892887
# (Iteration 701 / 1960) loss: 1.763680
# (Epoch 3 / 8) train acc: 0.345000; val_acc: 0.358000
# (Iteration 801 / 1960) loss: 1.731072
# (Iteration 901 / 1960) loss: 1.802646
# (Epoch 4 / 8) train acc: 0.384000; val_acc: 0.410000
# (Iteration 1001 / 1960) loss: 1.728706
# (Iteration 1101 / 1960) loss: 1.696877
# (Iteration 1201 / 1960) loss: 1.522469
# (Epoch 5 / 8) train acc: 0.432000; val_acc: 0.436000
# (Iteration 1301 / 1960) loss: 1.692379
# (Iteration 1401 / 1960) loss: 1.369141
# (Epoch 6 / 8) train acc: 0.490000; val_acc: 0.497000
# (Iteration 1501 / 1960) loss: 1.510438
# (Iteration 1601 / 1960) loss: 1.531182
# (Iteration 1701 / 1960) loss: 1.481790
# (Epoch 7 / 8) train acc: 0.554000; val_acc: 0.538000
# (Iteration 1801 / 1960) loss: 1.315327
# (Iteration 1901 / 1960) loss: 1.327657
# (Epoch 8 / 8) train acc: 0.562000; val_acc: 0.522000
# 6/25: Training with learning_rate: 0.1 and regularization_strength 0.0025
# (Iteration 1 / 1960) loss: 2.302686
# (Epoch 0 / 8) train acc: 0.089000; val_acc: 0.102000
# (Iteration 101 / 1960) loss: 2.278852
# (Iteration 201 / 1960) loss: 2.078531
# (Epoch 1 / 8) train acc: 0.267000; val_acc: 0.269000
# (Iteration 301 / 1960) loss: 1.953242
# (Iteration 401 / 1960) loss: 1.947261
# (Epoch 2 / 8) train acc: 0.355000; val_acc: 0.341000
# (Iteration 501 / 1960) loss: 1.974312
# (Iteration 601 / 1960) loss: 1.857847
# (Iteration 701 / 1960) loss: 1.920796
# (Epoch 3 / 8) train acc: 0.411000; val_acc: 0.436000
# (Iteration 801 / 1960) loss: 1.800044
# (Iteration 901 / 1960) loss: 1.800791
# (Epoch 4 / 8) train acc: 0.431000; val_acc: 0.444000
# (Iteration 1001 / 1960) loss: 1.660250
# (Iteration 1101 / 1960) loss: 1.775526
# (Iteration 1201 / 1960) loss: 1.642756
# (Epoch 5 / 8) train acc: 0.485000; val_acc: 0.462000
# (Iteration 1301 / 1960) loss: 1.603398
# (Iteration 1401 / 1960) loss: 1.680725
# (Epoch 6 / 8) train acc: 0.491000; val_acc: 0.498000
# (Iteration 1501 / 1960) loss: 1.587043
# (Iteration 1601 / 1960) loss: 1.590218
# (Iteration 1701 / 1960) loss: 1.391626
# (Epoch 7 / 8) train acc: 0.500000; val_acc: 0.527000
# (Iteration 1801 / 1960) loss: 1.498099
# (Iteration 1901 / 1960) loss: 1.502292
# (Epoch 8 / 8) train acc: 0.522000; val_acc: 0.514000
# 7/25: Training with learning_rate: 0.1125 and regularization_strength 0.0025
# (Iteration 1 / 1960) loss: 2.302712
# (Epoch 0 / 8) train acc: 0.103000; val_acc: 0.101000
# (Iteration 101 / 1960) loss: 2.302128
# (Iteration 201 / 1960) loss: 2.300002
# (Epoch 1 / 8) train acc: 0.100000; val_acc: 0.087000
# (Iteration 301 / 1960) loss: 2.274530
# (Iteration 401 / 1960) loss: 2.215893
# (Epoch 2 / 8) train acc: 0.146000; val_acc: 0.151000
# (Iteration 501 / 1960) loss: 2.278257
# (Iteration 601 / 1960) loss: 2.263712
# (Iteration 701 / 1960) loss: 2.211168
# (Epoch 3 / 8) train acc: 0.185000; val_acc: 0.182000
# (Iteration 801 / 1960) loss: 2.222046
# (Iteration 901 / 1960) loss: 2.207435
# (Epoch 4 / 8) train acc: 0.198000; val_acc: 0.180000
# (Iteration 1001 / 1960) loss: 2.232193
# (Iteration 1101 / 1960) loss: 2.226988
# (Iteration 1201 / 1960) loss: 2.212668
# (Epoch 5 / 8) train acc: 0.202000; val_acc: 0.176000
# (Iteration 1301 / 1960) loss: 2.242727
# (Iteration 1401 / 1960) loss: 2.176017
# (Epoch 6 / 8) train acc: 0.204000; val_acc: 0.173000
# (Iteration 1501 / 1960) loss: 2.238623
# (Iteration 1601 / 1960) loss: 2.250266
# (Iteration 1701 / 1960) loss: 2.239055
# (Epoch 7 / 8) train acc: 0.219000; val_acc: 0.178000
# (Iteration 1801 / 1960) loss: 2.201596
# (Iteration 1901 / 1960) loss: 2.195176
# (Epoch 8 / 8) train acc: 0.205000; val_acc: 0.177000
# 8/25: Training with learning_rate: 0.125 and regularization_strength 0.0025
# (Iteration 1 / 1960) loss: 2.302681
# (Epoch 0 / 8) train acc: 0.098000; val_acc: 0.112000
# (Iteration 101 / 1960) loss: 2.287653
# (Iteration 201 / 1960) loss: 1.991555
# (Epoch 1 / 8) train acc: 0.293000; val_acc: 0.325000
# (Iteration 301 / 1960) loss: 1.853419
# (Iteration 401 / 1960) loss: 1.768598
# (Epoch 2 / 8) train acc: 0.411000; val_acc: 0.429000
# (Iteration 501 / 1960) loss: 1.718956
# (Iteration 601 / 1960) loss: 1.777219
# (Iteration 701 / 1960) loss: 1.674516
# (Epoch 3 / 8) train acc: 0.421000; val_acc: 0.453000
# (Iteration 801 / 1960) loss: 1.642234
# (Iteration 901 / 1960) loss: 1.710196
# (Epoch 4 / 8) train acc: 0.471000; val_acc: 0.446000
# (Iteration 1001 / 1960) loss: 1.791794
# (Iteration 1101 / 1960) loss: 1.618345
# (Iteration 1201 / 1960) loss: 1.611241
# (Epoch 5 / 8) train acc: 0.462000; val_acc: 0.479000
# (Iteration 1301 / 1960) loss: 1.661783
# (Iteration 1401 / 1960) loss: 1.554860
# (Epoch 6 / 8) train acc: 0.480000; val_acc: 0.483000
# (Iteration 1501 / 1960) loss: 1.636770
# (Iteration 1601 / 1960) loss: 1.504615
# (Iteration 1701 / 1960) loss: 1.515340
# (Epoch 7 / 8) train acc: 0.461000; val_acc: 0.481000
# (Iteration 1801 / 1960) loss: 1.630732
# (Iteration 1901 / 1960) loss: 1.556074
# (Epoch 8 / 8) train acc: 0.487000; val_acc: 0.469000
# 9/25: Training with learning_rate: 0.1375 and regularization_strength 0.0025
# (Iteration 1 / 1960) loss: 2.302693
# (Epoch 0 / 8) train acc: 0.095000; val_acc: 0.098000
# (Iteration 101 / 1960) loss: 2.254236
# (Iteration 201 / 1960) loss: 2.116188
# (Epoch 1 / 8) train acc: 0.227000; val_acc: 0.230000
# (Iteration 301 / 1960) loss: 2.035946
# (Iteration 401 / 1960) loss: 1.992559
# (Epoch 2 / 8) train acc: 0.318000; val_acc: 0.301000
# (Iteration 501 / 1960) loss: 1.980138
# (Iteration 601 / 1960) loss: 1.990945
# (Iteration 701 / 1960) loss: 1.975725
# (Epoch 3 / 8) train acc: 0.337000; val_acc: 0.305000
# (Iteration 801 / 1960) loss: 1.994919
# (Iteration 901 / 1960) loss: 1.909471
# (Epoch 4 / 8) train acc: 0.315000; val_acc: 0.298000
# (Iteration 1001 / 1960) loss: 1.890860
# (Iteration 1101 / 1960) loss: 1.933988
# (Iteration 1201 / 1960) loss: 2.007924
# (Epoch 5 / 8) train acc: 0.380000; val_acc: 0.359000
# (Iteration 1301 / 1960) loss: 1.744360
# (Iteration 1401 / 1960) loss: 1.733867
# (Epoch 6 / 8) train acc: 0.392000; val_acc: 0.387000
# (Iteration 1501 / 1960) loss: 1.801047
# (Iteration 1601 / 1960) loss: 1.826874
# (Iteration 1701 / 1960) loss: 1.641644
# (Epoch 7 / 8) train acc: 0.420000; val_acc: 0.398000
# (Iteration 1801 / 1960) loss: 1.556019
# (Iteration 1901 / 1960) loss: 1.694346
# (Epoch 8 / 8) train acc: 0.401000; val_acc: 0.399000
# 10/25: Training with learning_rate: 0.15 and regularization_strength 0.0025
# (Iteration 1 / 1960) loss: 2.302699
# (Epoch 0 / 8) train acc: 0.096000; val_acc: 0.113000
# (Iteration 101 / 1960) loss: 2.263512
# (Iteration 201 / 1960) loss: 2.257510
# (Epoch 1 / 8) train acc: 0.121000; val_acc: 0.119000
# (Iteration 301 / 1960) loss: 2.205545
# (Iteration 401 / 1960) loss: 2.223167
# (Epoch 2 / 8) train acc: 0.115000; val_acc: 0.127000
# (Iteration 501 / 1960) loss: 2.238185
# (Iteration 601 / 1960) loss: 2.215330
# (Iteration 701 / 1960) loss: 2.237179
# (Epoch 3 / 8) train acc: 0.119000; val_acc: 0.132000
# (Iteration 801 / 1960) loss: 2.179827
# (Iteration 901 / 1960) loss: 2.193195
# (Epoch 4 / 8) train acc: 0.128000; val_acc: 0.135000
# (Iteration 1001 / 1960) loss: 2.161761
# (Iteration 1101 / 1960) loss: 2.188701
# (Iteration 1201 / 1960) loss: 2.220175
# (Epoch 5 / 8) train acc: 0.163000; val_acc: 0.198000
# (Iteration 1301 / 1960) loss: 2.232022
# (Iteration 1401 / 1960) loss: 2.090114
# (Epoch 6 / 8) train acc: 0.221000; val_acc: 0.282000
# (Iteration 1501 / 1960) loss: 2.101837
# (Iteration 1601 / 1960) loss: 1.962834
# (Iteration 1701 / 1960) loss: 1.945663
# (Epoch 7 / 8) train acc: 0.250000; val_acc: 0.291000
# (Iteration 1801 / 1960) loss: 2.020483
# (Iteration 1901 / 1960) loss: 1.949473
# (Epoch 8 / 8) train acc: 0.293000; val_acc: 0.288000
# 11/25: Training with learning_rate: 0.1 and regularization_strength 0.005
# (Iteration 1 / 1960) loss: 2.302824
# (Epoch 0 / 8) train acc: 0.123000; val_acc: 0.117000
# (Iteration 101 / 1960) loss: 2.302795
# (Iteration 201 / 1960) loss: 2.302775
# (Epoch 1 / 8) train acc: 0.096000; val_acc: 0.087000
# (Iteration 301 / 1960) loss: 2.302757
# (Iteration 401 / 1960) loss: 2.302742
# (Epoch 2 / 8) train acc: 0.089000; val_acc: 0.087000
# (Iteration 501 / 1960) loss: 2.302728
# (Iteration 601 / 1960) loss: 2.302715
# (Iteration 701 / 1960) loss: 2.302704
# (Epoch 3 / 8) train acc: 0.093000; val_acc: 0.087000
# (Iteration 801 / 1960) loss: 2.302694
# (Iteration 901 / 1960) loss: 2.302685
# (Epoch 4 / 8) train acc: 0.100000; val_acc: 0.087000
# (Iteration 1001 / 1960) loss: 2.302677
# (Iteration 1101 / 1960) loss: 2.302670
# (Iteration 1201 / 1960) loss: 2.302663
# (Epoch 5 / 8) train acc: 0.097000; val_acc: 0.087000
# (Iteration 1301 / 1960) loss: 2.302657
# (Iteration 1401 / 1960) loss: 2.302652
# (Epoch 6 / 8) train acc: 0.108000; val_acc: 0.087000
# (Iteration 1501 / 1960) loss: 2.302647
# (Iteration 1601 / 1960) loss: 2.302643
# (Iteration 1701 / 1960) loss: 2.302639
# (Epoch 7 / 8) train acc: 0.113000; val_acc: 0.087000
# (Iteration 1801 / 1960) loss: 2.302635
# (Iteration 1901 / 1960) loss: 2.302632
# (Epoch 8 / 8) train acc: 0.107000; val_acc: 0.087000
# 12/25: Training with learning_rate: 0.1125 and regularization_strength 0.005
# (Iteration 1 / 1960) loss: 2.302828
# (Epoch 0 / 8) train acc: 0.104000; val_acc: 0.104000
# (Iteration 101 / 1960) loss: 2.302792
# (Iteration 201 / 1960) loss: 2.302770
# (Epoch 1 / 8) train acc: 0.101000; val_acc: 0.087000
# (Iteration 301 / 1960) loss: 2.302751
# (Iteration 401 / 1960) loss: 2.302734
# (Epoch 2 / 8) train acc: 0.099000; val_acc: 0.087000
# (Iteration 501 / 1960) loss: 2.302719
# (Iteration 601 / 1960) loss: 2.302706
# (Iteration 701 / 1960) loss: 2.302694
# (Epoch 3 / 8) train acc: 0.100000; val_acc: 0.087000
# (Iteration 801 / 1960) loss: 2.302684
# (Iteration 901 / 1960) loss: 2.302675
# (Epoch 4 / 8) train acc: 0.082000; val_acc: 0.087000
# (Iteration 1001 / 1960) loss: 2.302667
# (Iteration 1101 / 1960) loss: 2.302660
# (Iteration 1201 / 1960) loss: 2.302653
# (Epoch 5 / 8) train acc: 0.083000; val_acc: 0.087000
# (Iteration 1301 / 1960) loss: 2.302647
# (Iteration 1401 / 1960) loss: 2.302642
# (Epoch 6 / 8) train acc: 0.100000; val_acc: 0.087000
# (Iteration 1501 / 1960) loss: 2.302637
# (Iteration 1601 / 1960) loss: 2.302633
# (Iteration 1701 / 1960) loss: 2.302629
# (Epoch 7 / 8) train acc: 0.099000; val_acc: 0.087000
# (Iteration 1801 / 1960) loss: 2.302626
# (Iteration 1901 / 1960) loss: 2.302623
# (Epoch 8 / 8) train acc: 0.127000; val_acc: 0.087000
# 13/25: Training with learning_rate: 0.125 and regularization_strength 0.005
# (Iteration 1 / 1960) loss: 2.302811
# (Epoch 0 / 8) train acc: 0.105000; val_acc: 0.119000
# (Iteration 101 / 1960) loss: 2.299736
# (Iteration 201 / 1960) loss: 2.280159
# (Epoch 1 / 8) train acc: 0.139000; val_acc: 0.151000
# (Iteration 301 / 1960) loss: 2.185053
# (Iteration 401 / 1960) loss: 2.229666
# (Epoch 2 / 8) train acc: 0.161000; val_acc: 0.154000
# (Iteration 501 / 1960) loss: 2.250925
# (Iteration 601 / 1960) loss: 2.193318
# (Iteration 701 / 1960) loss: 2.272064
# (Epoch 3 / 8) train acc: 0.164000; val_acc: 0.154000
# (Iteration 801 / 1960) loss: 2.191281
# (Iteration 901 / 1960) loss: 2.215240
# (Epoch 4 / 8) train acc: 0.238000; val_acc: 0.251000
# (Iteration 1001 / 1960) loss: 2.179336
# (Iteration 1101 / 1960) loss: 2.117458
# (Iteration 1201 / 1960) loss: 2.069056
# (Epoch 5 / 8) train acc: 0.262000; val_acc: 0.282000
# (Iteration 1301 / 1960) loss: 2.105567
# (Iteration 1401 / 1960) loss: 2.111246
# (Epoch 6 / 8) train acc: 0.280000; val_acc: 0.280000
# (Iteration 1501 / 1960) loss: 2.152881
# (Iteration 1601 / 1960) loss: 2.120256
# (Iteration 1701 / 1960) loss: 2.074091
# (Epoch 7 / 8) train acc: 0.288000; val_acc: 0.291000
# (Iteration 1801 / 1960) loss: 2.051806
# (Iteration 1901 / 1960) loss: 2.062969
# (Epoch 8 / 8) train acc: 0.311000; val_acc: 0.298000
# 14/25: Training with learning_rate: 0.1375 and regularization_strength 0.005
# (Iteration 1 / 1960) loss: 2.302803
# (Epoch 0 / 8) train acc: 0.129000; val_acc: 0.138000
# (Iteration 101 / 1960) loss: 2.302786
# (Iteration 201 / 1960) loss: 2.294132
# (Epoch 1 / 8) train acc: 0.087000; val_acc: 0.092000
# (Iteration 301 / 1960) loss: 2.123841
# (Iteration 401 / 1960) loss: 2.154221
# (Epoch 2 / 8) train acc: 0.190000; val_acc: 0.186000
# (Iteration 501 / 1960) loss: 2.132754
# (Iteration 601 / 1960) loss: 2.012290
# (Iteration 701 / 1960) loss: 2.032404
# (Epoch 3 / 8) train acc: 0.284000; val_acc: 0.283000
# (Iteration 801 / 1960) loss: 1.904962
# (Iteration 901 / 1960) loss: 1.918681
# (Epoch 4 / 8) train acc: 0.338000; val_acc: 0.350000
# (Iteration 1001 / 1960) loss: 1.860140
# (Iteration 1101 / 1960) loss: 1.999640
# (Iteration 1201 / 1960) loss: 1.875325
# (Epoch 5 / 8) train acc: 0.369000; val_acc: 0.350000
# (Iteration 1301 / 1960) loss: 1.797631
# (Iteration 1401 / 1960) loss: 1.734687
# (Epoch 6 / 8) train acc: 0.346000; val_acc: 0.348000
# (Iteration 1501 / 1960) loss: 1.774102
# (Iteration 1601 / 1960) loss: 1.800707
# (Iteration 1701 / 1960) loss: 1.845000
# (Epoch 7 / 8) train acc: 0.331000; val_acc: 0.346000
# (Iteration 1801 / 1960) loss: 1.776722
# (Iteration 1901 / 1960) loss: 1.700548
# (Epoch 8 / 8) train acc: 0.341000; val_acc: 0.347000
# 15/25: Training with learning_rate: 0.15 and regularization_strength 0.005
# (Iteration 1 / 1960) loss: 2.302809
# (Epoch 0 / 8) train acc: 0.099000; val_acc: 0.107000
# (Iteration 101 / 1960) loss: 2.302369
# (Iteration 201 / 1960) loss: 2.276397
# (Epoch 1 / 8) train acc: 0.146000; val_acc: 0.104000
# (Iteration 301 / 1960) loss: 2.206376
# (Iteration 401 / 1960) loss: 2.007672
# (Epoch 2 / 8) train acc: 0.305000; val_acc: 0.268000
# (Iteration 501 / 1960) loss: 1.961598
# (Iteration 601 / 1960) loss: 2.076028
# (Iteration 701 / 1960) loss: 2.012802
# (Epoch 3 / 8) train acc: 0.306000; val_acc: 0.286000
# (Iteration 801 / 1960) loss: 1.966635
# (Iteration 901 / 1960) loss: 1.944586
# (Epoch 4 / 8) train acc: 0.280000; val_acc: 0.282000
# (Iteration 1001 / 1960) loss: 1.931411
# (Iteration 1101 / 1960) loss: 1.933560
# (Iteration 1201 / 1960) loss: 1.805369
# (Epoch 5 / 8) train acc: 0.319000; val_acc: 0.281000
# (Iteration 1301 / 1960) loss: 1.905614
# (Iteration 1401 / 1960) loss: 1.937199
# (Epoch 6 / 8) train acc: 0.324000; val_acc: 0.275000
# (Iteration 1501 / 1960) loss: 1.853691
# (Iteration 1601 / 1960) loss: 1.965575
# (Iteration 1701 / 1960) loss: 1.827404
# (Epoch 7 / 8) train acc: 0.309000; val_acc: 0.283000
# (Iteration 1801 / 1960) loss: 1.911377
# (Iteration 1901 / 1960) loss: 1.891048
# (Epoch 8 / 8) train acc: 0.321000; val_acc: 0.292000
# 16/25: Training with learning_rate: 0.1 and regularization_strength 0.0075
# (Iteration 1 / 1960) loss: 2.302938
# (Epoch 0 / 8) train acc: 0.078000; val_acc: 0.106000
# (Iteration 101 / 1960) loss: 2.302068
# (Iteration 201 / 1960) loss: 2.286147
# (Epoch 1 / 8) train acc: 0.152000; val_acc: 0.154000
# (Iteration 301 / 1960) loss: 2.260847
# (Iteration 401 / 1960) loss: 2.196182
# (Epoch 2 / 8) train acc: 0.240000; val_acc: 0.224000
# (Iteration 501 / 1960) loss: 2.185971
# (Iteration 601 / 1960) loss: 2.102034
# (Iteration 701 / 1960) loss: 2.037374
# (Epoch 3 / 8) train acc: 0.308000; val_acc: 0.278000
# (Iteration 801 / 1960) loss: 2.058112
# (Iteration 901 / 1960) loss: 1.988266
# (Epoch 4 / 8) train acc: 0.368000; val_acc: 0.347000
# (Iteration 1001 / 1960) loss: 2.064330
# (Iteration 1101 / 1960) loss: 1.943056
# (Iteration 1201 / 1960) loss: 2.004780
# (Epoch 5 / 8) train acc: 0.363000; val_acc: 0.360000
# (Iteration 1301 / 1960) loss: 1.840045
# (Iteration 1401 / 1960) loss: 1.950361
# (Epoch 6 / 8) train acc: 0.378000; val_acc: 0.361000
# (Iteration 1501 / 1960) loss: 1.859302
# (Iteration 1601 / 1960) loss: 1.997377
# (Iteration 1701 / 1960) loss: 1.965692
# (Epoch 7 / 8) train acc: 0.370000; val_acc: 0.365000
# (Iteration 1801 / 1960) loss: 1.926815
# (Iteration 1901 / 1960) loss: 1.925311
# (Epoch 8 / 8) train acc: 0.383000; val_acc: 0.368000
# 17/25: Training with learning_rate: 0.1125 and regularization_strength 0.0075
# (Iteration 1 / 1960) loss: 2.302922
# (Epoch 0 / 8) train acc: 0.100000; val_acc: 0.107000
# (Iteration 101 / 1960) loss: 2.298412
# (Iteration 201 / 1960) loss: 2.238991
# (Epoch 1 / 8) train acc: 0.212000; val_acc: 0.233000
# (Iteration 301 / 1960) loss: 2.134912
# (Iteration 401 / 1960) loss: 2.092144
# (Epoch 2 / 8) train acc: 0.276000; val_acc: 0.254000
# (Iteration 501 / 1960) loss: 2.094399
# (Iteration 601 / 1960) loss: 2.040847
# (Iteration 701 / 1960) loss: 2.031007
# (Epoch 3 / 8) train acc: 0.329000; val_acc: 0.346000
# (Iteration 801 / 1960) loss: 1.966732
# (Iteration 901 / 1960) loss: 1.897073
# (Epoch 4 / 8) train acc: 0.375000; val_acc: 0.361000
# (Iteration 1001 / 1960) loss: 1.889808
# (Iteration 1101 / 1960) loss: 2.026379
# (Iteration 1201 / 1960) loss: 1.994324
# (Epoch 5 / 8) train acc: 0.388000; val_acc: 0.369000
# (Iteration 1301 / 1960) loss: 2.020644
# (Iteration 1401 / 1960) loss: 1.896741
# (Epoch 6 / 8) train acc: 0.377000; val_acc: 0.367000
# (Iteration 1501 / 1960) loss: 2.047477
# (Iteration 1601 / 1960) loss: 1.852654
# (Iteration 1701 / 1960) loss: 1.953616
# (Epoch 7 / 8) train acc: 0.386000; val_acc: 0.369000
# (Iteration 1801 / 1960) loss: 1.819828
# (Iteration 1901 / 1960) loss: 1.953845
# (Epoch 8 / 8) train acc: 0.375000; val_acc: 0.372000
# 18/25: Training with learning_rate: 0.125 and regularization_strength 0.0075
# (Iteration 1 / 1960) loss: 2.302924
# (Epoch 0 / 8) train acc: 0.096000; val_acc: 0.112000
# (Iteration 101 / 1960) loss: 2.302679
# (Iteration 201 / 1960) loss: 2.300818
# (Epoch 1 / 8) train acc: 0.138000; val_acc: 0.138000
# (Iteration 301 / 1960) loss: 2.274772
# (Iteration 401 / 1960) loss: 2.253649
# (Epoch 2 / 8) train acc: 0.155000; val_acc: 0.163000
# (Iteration 501 / 1960) loss: 2.281304
# (Iteration 601 / 1960) loss: 2.246118
# (Iteration 701 / 1960) loss: 2.259395
# (Epoch 3 / 8) train acc: 0.158000; val_acc: 0.163000
# (Iteration 801 / 1960) loss: 2.291579
# (Iteration 901 / 1960) loss: 2.263767
# (Epoch 4 / 8) train acc: 0.161000; val_acc: 0.162000
# (Iteration 1001 / 1960) loss: 2.276465
# (Iteration 1101 / 1960) loss: 2.299649
# (Iteration 1201 / 1960) loss: 2.289350
# (Epoch 5 / 8) train acc: 0.156000; val_acc: 0.163000
# (Iteration 1301 / 1960) loss: 2.266882
# (Iteration 1401 / 1960) loss: 2.314300
# (Epoch 6 / 8) train acc: 0.164000; val_acc: 0.159000
# (Iteration 1501 / 1960) loss: 2.281234
# (Iteration 1601 / 1960) loss: 2.279613
# (Iteration 1701 / 1960) loss: 2.291528
# (Epoch 7 / 8) train acc: 0.175000; val_acc: 0.160000
# (Iteration 1801 / 1960) loss: 2.289308
# (Iteration 1901 / 1960) loss: 2.274773
# (Epoch 8 / 8) train acc: 0.148000; val_acc: 0.158000
# 19/25: Training with learning_rate: 0.1375 and regularization_strength 0.0075
# (Iteration 1 / 1960) loss: 2.302925
# (Epoch 0 / 8) train acc: 0.115000; val_acc: 0.112000
# (Iteration 101 / 1960) loss: 2.280966
# (Iteration 201 / 1960) loss: 2.189121
# (Epoch 1 / 8) train acc: 0.226000; val_acc: 0.193000
# (Iteration 301 / 1960) loss: 2.135392
# (Iteration 401 / 1960) loss: 2.184612
# (Epoch 2 / 8) train acc: 0.289000; val_acc: 0.283000
# (Iteration 501 / 1960) loss: 2.065445
# (Iteration 601 / 1960) loss: 2.014055
# (Iteration 701 / 1960) loss: 2.099486
# (Epoch 3 / 8) train acc: 0.303000; val_acc: 0.278000
# (Iteration 801 / 1960) loss: 2.072363
# (Iteration 901 / 1960) loss: 2.131829
# (Epoch 4 / 8) train acc: 0.297000; val_acc: 0.281000
# (Iteration 1001 / 1960) loss: 2.107588
# (Iteration 1101 / 1960) loss: 2.157610
# (Iteration 1201 / 1960) loss: 2.130192
# (Epoch 5 / 8) train acc: 0.286000; val_acc: 0.277000
# (Iteration 1301 / 1960) loss: 2.081906
# (Iteration 1401 / 1960) loss: 2.001300
# (Epoch 6 / 8) train acc: 0.300000; val_acc: 0.280000
# (Iteration 1501 / 1960) loss: 2.105560
# (Iteration 1601 / 1960) loss: 2.084560
# (Iteration 1701 / 1960) loss: 2.057280
# (Epoch 7 / 8) train acc: 0.273000; val_acc: 0.286000
# (Iteration 1801 / 1960) loss: 2.063504
# (Iteration 1901 / 1960) loss: 2.040599
# (Epoch 8 / 8) train acc: 0.301000; val_acc: 0.281000
# 20/25: Training with learning_rate: 0.15 and regularization_strength 0.0075
# (Iteration 1 / 1960) loss: 2.302934
# (Epoch 0 / 8) train acc: 0.113000; val_acc: 0.079000
# (Iteration 101 / 1960) loss: 2.291326
# (Iteration 201 / 1960) loss: 2.186153
# (Epoch 1 / 8) train acc: 0.142000; val_acc: 0.156000
# (Iteration 301 / 1960) loss: 2.225083
# (Iteration 401 / 1960) loss: 2.239777
# (Epoch 2 / 8) train acc: 0.197000; val_acc: 0.205000
# (Iteration 501 / 1960) loss: 2.196261
# (Iteration 601 / 1960) loss: 2.213971
# (Iteration 701 / 1960) loss: 2.085498
# (Epoch 3 / 8) train acc: 0.237000; val_acc: 0.225000
# (Iteration 801 / 1960) loss: 2.169443
# (Iteration 901 / 1960) loss: 2.233378
# (Epoch 4 / 8) train acc: 0.229000; val_acc: 0.226000
# (Iteration 1001 / 1960) loss: 2.092821
# (Iteration 1101 / 1960) loss: 2.245010
# (Iteration 1201 / 1960) loss: 2.207537
# (Epoch 5 / 8) train acc: 0.241000; val_acc: 0.229000
# (Iteration 1301 / 1960) loss: 2.143866
# (Iteration 1401 / 1960) loss: 2.185395
# (Epoch 6 / 8) train acc: 0.227000; val_acc: 0.221000
# (Iteration 1501 / 1960) loss: 2.176304
# (Iteration 1601 / 1960) loss: 2.142366
# (Iteration 1701 / 1960) loss: 2.210383
# (Epoch 7 / 8) train acc: 0.236000; val_acc: 0.228000
# (Iteration 1801 / 1960) loss: 2.131129
# (Iteration 1901 / 1960) loss: 2.152702
# (Epoch 8 / 8) train acc: 0.230000; val_acc: 0.239000
# 21/25: Training with learning_rate: 0.1 and regularization_strength 0.01
# (Iteration 1 / 1960) loss: 2.303045
# (Epoch 0 / 8) train acc: 0.109000; val_acc: 0.079000
# (Iteration 101 / 1960) loss: 2.298371
# (Iteration 201 / 1960) loss: 2.107222
# (Epoch 1 / 8) train acc: 0.229000; val_acc: 0.223000
# (Iteration 301 / 1960) loss: 2.087892
# (Iteration 401 / 1960) loss: 1.978376
# (Epoch 2 / 8) train acc: 0.319000; val_acc: 0.332000
# (Iteration 501 / 1960) loss: 2.000695
# (Iteration 601 / 1960) loss: 1.918288
# (Iteration 701 / 1960) loss: 1.962587
# (Epoch 3 / 8) train acc: 0.319000; val_acc: 0.334000
# (Iteration 801 / 1960) loss: 1.974163
# (Iteration 901 / 1960) loss: 1.874574
# (Epoch 4 / 8) train acc: 0.310000; val_acc: 0.331000
# (Iteration 1001 / 1960) loss: 2.035750
# (Iteration 1101 / 1960) loss: 1.999549
# (Iteration 1201 / 1960) loss: 1.966161
# (Epoch 5 / 8) train acc: 0.312000; val_acc: 0.327000
# (Iteration 1301 / 1960) loss: 2.018052
# (Iteration 1401 / 1960) loss: 2.010278
# (Epoch 6 / 8) train acc: 0.335000; val_acc: 0.333000
# (Iteration 1501 / 1960) loss: 2.009065
# (Iteration 1601 / 1960) loss: 1.886073
# (Iteration 1701 / 1960) loss: 1.971696
# (Epoch 7 / 8) train acc: 0.362000; val_acc: 0.335000
# (Iteration 1801 / 1960) loss: 2.011793
# (Iteration 1901 / 1960) loss: 1.873372
# (Epoch 8 / 8) train acc: 0.349000; val_acc: 0.331000
# 22/25: Training with learning_rate: 0.1125 and regularization_strength 0.01
# (Iteration 1 / 1960) loss: 2.303042
# (Epoch 0 / 8) train acc: 0.095000; val_acc: 0.082000
# (Iteration 101 / 1960) loss: 2.297280
# (Iteration 201 / 1960) loss: 2.149078
# (Epoch 1 / 8) train acc: 0.172000; val_acc: 0.185000
# (Iteration 301 / 1960) loss: 2.152925
# (Iteration 401 / 1960) loss: 2.140702
# (Epoch 2 / 8) train acc: 0.254000; val_acc: 0.254000
# (Iteration 501 / 1960) loss: 2.082188
# (Iteration 601 / 1960) loss: 2.067872
# (Iteration 701 / 1960) loss: 2.096116
# (Epoch 3 / 8) train acc: 0.302000; val_acc: 0.322000
# (Iteration 801 / 1960) loss: 2.062366
# (Iteration 901 / 1960) loss: 2.059641
# (Epoch 4 / 8) train acc: 0.335000; val_acc: 0.327000
# (Iteration 1001 / 1960) loss: 2.041174
# (Iteration 1101 / 1960) loss: 2.008994
# (Iteration 1201 / 1960) loss: 2.013261
# (Epoch 5 / 8) train acc: 0.326000; val_acc: 0.323000
# (Iteration 1301 / 1960) loss: 1.964017
# (Iteration 1401 / 1960) loss: 1.973781
# (Epoch 6 / 8) train acc: 0.324000; val_acc: 0.326000
# (Iteration 1501 / 1960) loss: 1.960279
# (Iteration 1601 / 1960) loss: 1.967805
# (Iteration 1701 / 1960) loss: 1.928021
# (Epoch 7 / 8) train acc: 0.322000; val_acc: 0.331000
# (Iteration 1801 / 1960) loss: 2.062937
# (Iteration 1901 / 1960) loss: 2.079773
# (Epoch 8 / 8) train acc: 0.326000; val_acc: 0.333000
# 23/25: Training with learning_rate: 0.125 and regularization_strength 0.01
# (Iteration 1 / 1960) loss: 2.303056
# (Epoch 0 / 8) train acc: 0.092000; val_acc: 0.107000
# (Iteration 101 / 1960) loss: 2.298853
# (Iteration 201 / 1960) loss: 2.268999
# (Epoch 1 / 8) train acc: 0.187000; val_acc: 0.168000
# (Iteration 301 / 1960) loss: 2.186961
# (Iteration 401 / 1960) loss: 2.169367
# (Epoch 2 / 8) train acc: 0.168000; val_acc: 0.177000
# (Iteration 501 / 1960) loss: 2.176547
# (Iteration 601 / 1960) loss: 2.189745
# (Iteration 701 / 1960) loss: 2.139858
# (Epoch 3 / 8) train acc: 0.202000; val_acc: 0.206000
# (Iteration 801 / 1960) loss: 2.198082
# (Iteration 901 / 1960) loss: 2.208981
# (Epoch 4 / 8) train acc: 0.185000; val_acc: 0.209000
# (Iteration 1001 / 1960) loss: 2.087032
# (Iteration 1101 / 1960) loss: 2.140741
# (Iteration 1201 / 1960) loss: 2.200308
# (Epoch 5 / 8) train acc: 0.219000; val_acc: 0.207000
# (Iteration 1301 / 1960) loss: 2.098790
# (Iteration 1401 / 1960) loss: 2.144517
# (Epoch 6 / 8) train acc: 0.202000; val_acc: 0.207000
# (Iteration 1501 / 1960) loss: 2.158102
# (Iteration 1601 / 1960) loss: 2.161251
# (Iteration 1701 / 1960) loss: 2.114753
# (Epoch 7 / 8) train acc: 0.204000; val_acc: 0.204000
# (Iteration 1801 / 1960) loss: 2.199248
# (Iteration 1901 / 1960) loss: 2.056846
# (Epoch 8 / 8) train acc: 0.198000; val_acc: 0.202000
# 24/25: Training with learning_rate: 0.1375 and regularization_strength 0.01
# (Iteration 1 / 1960) loss: 2.303049
# (Epoch 0 / 8) train acc: 0.104000; val_acc: 0.087000
# (Iteration 101 / 1960) loss: 2.291659
# (Iteration 201 / 1960) loss: 2.190515
# (Epoch 1 / 8) train acc: 0.199000; val_acc: 0.180000
# (Iteration 301 / 1960) loss: 2.209030
# (Iteration 401 / 1960) loss: 2.122850
# (Epoch 2 / 8) train acc: 0.182000; val_acc: 0.182000
# (Iteration 501 / 1960) loss: 2.158350
# (Iteration 601 / 1960) loss: 2.203616
# (Iteration 701 / 1960) loss: 2.166689
# (Epoch 3 / 8) train acc: 0.215000; val_acc: 0.182000
# (Iteration 801 / 1960) loss: 2.177386
# (Iteration 901 / 1960) loss: 2.209957
# (Epoch 4 / 8) train acc: 0.202000; val_acc: 0.184000
# (Iteration 1001 / 1960) loss: 2.158821
# (Iteration 1101 / 1960) loss: 2.168266
# (Iteration 1201 / 1960) loss: 2.211855
# (Epoch 5 / 8) train acc: 0.184000; val_acc: 0.180000
# (Iteration 1301 / 1960) loss: 2.191971
# (Iteration 1401 / 1960) loss: 2.084263
# (Epoch 6 / 8) train acc: 0.208000; val_acc: 0.186000
# (Iteration 1501 / 1960) loss: 2.155139
# (Iteration 1601 / 1960) loss: 2.139329
# (Iteration 1701 / 1960) loss: 2.215164
# (Epoch 7 / 8) train acc: 0.188000; val_acc: 0.184000
# (Iteration 1801 / 1960) loss: 2.119943
# (Iteration 1901 / 1960) loss: 2.185648
# (Epoch 8 / 8) train acc: 0.208000; val_acc: 0.189000
# 25/25: Training with learning_rate: 0.15 and regularization_strength 0.01
# (Iteration 1 / 1960) loss: 2.303048
# (Epoch 0 / 8) train acc: 0.085000; val_acc: 0.114000
# (Iteration 101 / 1960) loss: 2.293947
# (Iteration 201 / 1960) loss: 2.143776
# (Epoch 1 / 8) train acc: 0.259000; val_acc: 0.298000
# (Iteration 301 / 1960) loss: 2.094913
# (Iteration 401 / 1960) loss: 2.108637
# (Epoch 2 / 8) train acc: 0.343000; val_acc: 0.354000
# (Iteration 501 / 1960) loss: 1.999227
# (Iteration 601 / 1960) loss: 2.059942
# (Iteration 701 / 1960) loss: 1.917761
# (Epoch 3 / 8) train acc: 0.370000; val_acc: 0.372000
# (Iteration 801 / 1960) loss: 2.017963
# (Iteration 901 / 1960) loss: 1.948341
# (Epoch 4 / 8) train acc: 0.334000; val_acc: 0.382000
# (Iteration 1001 / 1960) loss: 2.067831
# (Iteration 1101 / 1960) loss: 1.928484
# (Iteration 1201 / 1960) loss: 2.005759
# (Epoch 5 / 8) train acc: 0.363000; val_acc: 0.373000
# (Iteration 1301 / 1960) loss: 2.050342
# (Iteration 1401 / 1960) loss: 1.993219
# (Epoch 6 / 8) train acc: 0.361000; val_acc: 0.378000
# (Iteration 1501 / 1960) loss: 2.050294
# (Iteration 1601 / 1960) loss: 2.011945
# (Iteration 1701 / 1960) loss: 2.017105
# (Epoch 7 / 8) train acc: 0.358000; val_acc: 0.378000
# (Iteration 1801 / 1960) loss: 2.017264
# (Iteration 1901 / 1960) loss: 1.837024
# (Epoch 8 / 8) train acc: 0.373000; val_acc: 0.376000
# lr 1.000000e-01 reg 0.000000e+00 train accuracy: 0.443000 val accuracy: 0.431000
# lr 1.000000e-01 reg 2.500000e-03 train accuracy: 0.522000 val accuracy: 0.514000
# lr 1.000000e-01 reg 5.000000e-03 train accuracy: 0.107000 val accuracy: 0.087000
# lr 1.000000e-01 reg 7.500000e-03 train accuracy: 0.383000 val accuracy: 0.368000
# lr 1.000000e-01 reg 1.000000e-02 train accuracy: 0.349000 val accuracy: 0.331000
# lr 1.125000e-01 reg 0.000000e+00 train accuracy: 0.521000 val accuracy: 0.511000
# lr 1.125000e-01 reg 2.500000e-03 train accuracy: 0.205000 val accuracy: 0.177000
# lr 1.125000e-01 reg 5.000000e-03 train accuracy: 0.127000 val accuracy: 0.087000
# lr 1.125000e-01 reg 7.500000e-03 train accuracy: 0.375000 val accuracy: 0.372000
# lr 1.125000e-01 reg 1.000000e-02 train accuracy: 0.326000 val accuracy: 0.333000
# lr 1.250000e-01 reg 0.000000e+00 train accuracy: 0.335000 val accuracy: 0.329000
# lr 1.250000e-01 reg 2.500000e-03 train accuracy: 0.487000 val accuracy: 0.469000
# lr 1.250000e-01 reg 5.000000e-03 train accuracy: 0.311000 val accuracy: 0.298000
# lr 1.250000e-01 reg 7.500000e-03 train accuracy: 0.148000 val accuracy: 0.158000
# lr 1.250000e-01 reg 1.000000e-02 train accuracy: 0.198000 val accuracy: 0.202000
# lr 1.375000e-01 reg 0.000000e+00 train accuracy: 0.589000 val accuracy: 0.559000
# lr 1.375000e-01 reg 2.500000e-03 train accuracy: 0.401000 val accuracy: 0.399000
# lr 1.375000e-01 reg 5.000000e-03 train accuracy: 0.341000 val accuracy: 0.347000
# lr 1.375000e-01 reg 7.500000e-03 train accuracy: 0.301000 val accuracy: 0.281000
# lr 1.375000e-01 reg 1.000000e-02 train accuracy: 0.208000 val accuracy: 0.189000
# lr 1.500000e-01 reg 0.000000e+00 train accuracy: 0.562000 val accuracy: 0.522000
# lr 1.500000e-01 reg 2.500000e-03 train accuracy: 0.293000 val accuracy: 0.288000
# lr 1.500000e-01 reg 5.000000e-03 train accuracy: 0.321000 val accuracy: 0.292000
# lr 1.500000e-01 reg 7.500000e-03 train accuracy: 0.230000 val accuracy: 0.239000
# lr 1.500000e-01 reg 1.000000e-02 train accuracy: 0.373000 val accuracy: 0.376000
# best validation accuracy achieved during cross-validation: 0.559000

# %%
# Visualize the cross-validation results
import math
import pdb

# pdb.set_trace()

# x_scatter = [math.log10(x[0]) for x in results]
# y_scatter = [math.log10(x[1]) for x in results]

# # plot training accuracy
# marker_size = 100
# colors = [results[x][0] for x in results]
# plt.subplot(2, 1, 1)
# plt.tight_layout(pad=3)
# plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
# plt.colorbar()
# plt.xlabel('log learning rate')
# plt.ylabel('log regularization strength')
# plt.title('CIFAR-10 training accuracy')

# # plot validation accuracy
# colors = [results[x][1] for x in results] # default size of markers is 20
# plt.subplot(2, 1, 2)
# plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
# plt.colorbar()
# plt.xlabel('log learning rate')
# plt.ylabel('log regularization strength')
# plt.title('CIFAR-10 validation accuracy')
# plt.show()


x_scatter = [(x[0]) for x in results]
y_scatter = [(x[1]) for x in results]
# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.tight_layout(pad=3)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('learning rate')
plt.ylabel('regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('learning rate')
plt.ylabel('regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.544

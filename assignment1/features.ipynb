# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

from cs231n.classifiers import LinearSVM

for regularization_strength in regularization_strengths:
    for learning_rate in learning_rates:
        svm = LinearSVM()        
        print("lr ", learning_rate, " reg ", regularization_strength)
        
        loss_hist = svm.train(X_train_feats, y_train, learning_rate=learning_rate, reg=regularization_strength,
                            num_iters=3000, verbose=True)
        
        y_train_pred = svm.predict(X_train_feats)
        training_accuracy = np.mean(y_train == y_train_pred)
        print('training accuracy: %f' % training_accuracy, )

        y_val_pred = svm.predict(X_val_feats)
        validation_accuracy = np.mean(y_val == y_val_pred)
        print('validation accuracy: %f' % validation_accuracy, )
        results[(learning_rate, regularization_strength)] = (training_accuracy, validation_accuracy)

        if validation_accuracy > best_val:
            best_val = validation_accuracy
            best_svm = svm

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved: %f' % best_val)
# Out:
# lr  1e-09  reg  50000.0
# iteration 0 / 3000: loss 84.777668
# iteration 100 / 3000: loss 83.287326
# iteration 200 / 3000: loss 81.818502
# iteration 300 / 3000: loss 80.364949
# iteration 400 / 3000: loss 78.957968
# iteration 500 / 3000: loss 77.563555
# iteration 600 / 3000: loss 76.200584
# iteration 700 / 3000: loss 74.884256
# iteration 800 / 3000: loss 73.587570
# iteration 900 / 3000: loss 72.292823
# iteration 1000 / 3000: loss 71.046824
# iteration 1100 / 3000: loss 69.795096
# iteration 1200 / 3000: loss 68.615433
# iteration 1300 / 3000: loss 67.430719
# iteration 1400 / 3000: loss 66.271799
# iteration 1500 / 3000: loss 65.139536
# iteration 1600 / 3000: loss 64.027443
# iteration 1700 / 3000: loss 62.945839
# iteration 1800 / 3000: loss 61.866466
# iteration 1900 / 3000: loss 60.812722
# iteration 2000 / 3000: loss 59.802028
# iteration 2100 / 3000: loss 58.788785
# iteration 2200 / 3000: loss 57.809762
# iteration 2300 / 3000: loss 56.828766
# iteration 2400 / 3000: loss 55.902660
# iteration 2500 / 3000: loss 54.963381
# iteration 2600 / 3000: loss 54.043020
# iteration 2700 / 3000: loss 53.171210
# iteration 2800 / 3000: loss 52.280502
# iteration 2900 / 3000: loss 51.429422
# training accuracy: 0.086673
# validation accuracy: 0.102000
# lr  1e-08  reg  50000.0
# iteration 0 / 3000: loss 86.302423
# iteration 100 / 3000: loss 72.285615
# iteration 200 / 3000: loss 60.803607
# iteration 300 / 3000: loss 51.421076
# iteration 400 / 3000: loss 43.724081
# iteration 500 / 3000: loss 37.425557
# iteration 600 / 3000: loss 32.272716
# iteration 700 / 3000: loss 28.044761
# iteration 800 / 3000: loss 24.595959
# iteration 900 / 3000: loss 21.766507
# iteration 1000 / 3000: loss 19.451577
# iteration 1100 / 3000: loss 17.559480
# iteration 1200 / 3000: loss 16.003903
# iteration 1300 / 3000: loss 14.734956
# iteration 1400 / 3000: loss 13.696322
# iteration 1500 / 3000: loss 12.843013
# iteration 1600 / 3000: loss 12.141469
# iteration 1700 / 3000: loss 11.572688
# iteration 1800 / 3000: loss 11.107526
# iteration 1900 / 3000: loss 10.725525
# iteration 2000 / 3000: loss 10.411166
# iteration 2100 / 3000: loss 10.156216
# iteration 2200 / 3000: loss 9.947179
# iteration 2300 / 3000: loss 9.774669
# iteration 2400 / 3000: loss 9.632685
# iteration 2500 / 3000: loss 9.518099
# iteration 2600 / 3000: loss 9.424908
# iteration 2700 / 3000: loss 9.348261
# iteration 2800 / 3000: loss 9.283978
# iteration 2900 / 3000: loss 9.232618
# training accuracy: 0.096939
# validation accuracy: 0.096000
# lr  1e-07  reg  50000.0
# iteration 0 / 3000: loss 85.217804
# iteration 100 / 3000: loss 19.210776
# iteration 200 / 3000: loss 10.368554
# iteration 300 / 3000: loss 9.182097
# iteration 400 / 3000: loss 9.024228
# iteration 500 / 3000: loss 9.003026
# iteration 600 / 3000: loss 9.000034
# iteration 700 / 3000: loss 8.999674
# iteration 800 / 3000: loss 8.999692
# iteration 900 / 3000: loss 8.999636
# iteration 1000 / 3000: loss 8.999612
# iteration 1100 / 3000: loss 8.999641
# iteration 1200 / 3000: loss 8.999723
# iteration 1300 / 3000: loss 8.999706
# iteration 1400 / 3000: loss 8.999707
# iteration 1500 / 3000: loss 8.999662
# iteration 1600 / 3000: loss 8.999616
# iteration 1700 / 3000: loss 8.999708
# iteration 1800 / 3000: loss 8.999637
# iteration 1900 / 3000: loss 8.999594
# iteration 2000 / 3000: loss 8.999717
# iteration 2100 / 3000: loss 8.999692
# iteration 2200 / 3000: loss 8.999563
# iteration 2300 / 3000: loss 8.999541
# iteration 2400 / 3000: loss 8.999645
# iteration 2500 / 3000: loss 8.999610
# iteration 2600 / 3000: loss 8.999605
# iteration 2700 / 3000: loss 8.999582
# iteration 2800 / 3000: loss 8.999624
# iteration 2900 / 3000: loss 8.999618
# training accuracy: 0.418143
# validation accuracy: 0.419000
# lr  1e-09  reg  500000.0
# iteration 0 / 3000: loss 755.305305
# iteration 100 / 3000: loss 619.960755
# iteration 200 / 3000: loss 509.167902
# iteration 300 / 3000: loss 418.457537
# iteration 400 / 3000: loss 344.207975
# iteration 500 / 3000: loss 283.410557
# iteration 600 / 3000: loss 233.648373
# iteration 700 / 3000: loss 192.906784
# iteration 800 / 3000: loss 159.554913
# iteration 900 / 3000: loss 132.251934
# iteration 1000 / 3000: loss 109.899970
# iteration 1100 / 3000: loss 91.596823
# iteration 1200 / 3000: loss 76.621688
# iteration 1300 / 3000: loss 64.359280
# iteration 1400 / 3000: loss 54.317484
# iteration 1500 / 3000: loss 46.097396
# iteration 1600 / 3000: loss 39.371196
# iteration 1700 / 3000: loss 33.863646
# iteration 1800 / 3000: loss 29.355880
# iteration 1900 / 3000: loss 25.664539
# iteration 2000 / 3000: loss 22.643112
# iteration 2100 / 3000: loss 20.166750
# iteration 2200 / 3000: loss 18.142091
# iteration 2300 / 3000: loss 16.483240
# iteration 2400 / 3000: loss 15.126687
# iteration 2500 / 3000: loss 14.016318
# iteration 2600 / 3000: loss 13.107421
# iteration 2700 / 3000: loss 12.361183
# iteration 2800 / 3000: loss 11.751062
# iteration 2900 / 3000: loss 11.254147
# training accuracy: 0.120224
# validation accuracy: 0.112000
# lr  1e-08  reg  500000.0
# iteration 0 / 3000: loss 800.304705
# iteration 100 / 3000: loss 115.017783
# iteration 200 / 3000: loss 23.203604
# iteration 300 / 3000: loss 10.903164
# iteration 400 / 3000: loss 9.254908
# iteration 500 / 3000: loss 9.034092
# iteration 600 / 3000: loss 9.004564
# iteration 700 / 3000: loss 9.000579
# iteration 800 / 3000: loss 9.000044
# iteration 900 / 3000: loss 8.999977
# iteration 1000 / 3000: loss 8.999967
# iteration 1100 / 3000: loss 8.999960
# iteration 1200 / 3000: loss 8.999969
# iteration 1300 / 3000: loss 8.999968
# iteration 1400 / 3000: loss 8.999959
# iteration 1500 / 3000: loss 8.999968
# iteration 1600 / 3000: loss 8.999970
# iteration 1700 / 3000: loss 8.999965
# iteration 1800 / 3000: loss 8.999965
# iteration 1900 / 3000: loss 8.999970
# iteration 2000 / 3000: loss 8.999962
# iteration 2100 / 3000: loss 8.999962
# iteration 2200 / 3000: loss 8.999966
# iteration 2300 / 3000: loss 8.999966
# iteration 2400 / 3000: loss 8.999968
# iteration 2500 / 3000: loss 8.999965
# iteration 2600 / 3000: loss 8.999956
# iteration 2700 / 3000: loss 8.999956
# iteration 2800 / 3000: loss 8.999961
# iteration 2900 / 3000: loss 8.999969
# training accuracy: 0.413449
# validation accuracy: 0.401000
# lr  1e-07  reg  500000.0
# iteration 0 / 3000: loss 748.770112
# iteration 100 / 3000: loss 8.999973
# iteration 200 / 3000: loss 8.999971
# iteration 300 / 3000: loss 8.999962
# iteration 400 / 3000: loss 8.999965
# iteration 500 / 3000: loss 8.999956
# iteration 600 / 3000: loss 8.999974
# iteration 700 / 3000: loss 8.999966
# iteration 800 / 3000: loss 8.999961
# iteration 900 / 3000: loss 8.999969
# iteration 1000 / 3000: loss 8.999971
# iteration 1100 / 3000: loss 8.999971
# iteration 1200 / 3000: loss 8.999960
# iteration 1300 / 3000: loss 8.999964
# iteration 1400 / 3000: loss 8.999972
# iteration 1500 / 3000: loss 8.999966
# iteration 1600 / 3000: loss 8.999961
# iteration 1700 / 3000: loss 8.999961
# iteration 1800 / 3000: loss 8.999969
# iteration 1900 / 3000: loss 8.999964
# iteration 2000 / 3000: loss 8.999974
# iteration 2100 / 3000: loss 8.999960
# iteration 2200 / 3000: loss 8.999977
# iteration 2300 / 3000: loss 8.999967
# iteration 2400 / 3000: loss 8.999964
# iteration 2500 / 3000: loss 8.999967
# iteration 2600 / 3000: loss 8.999969
# iteration 2700 / 3000: loss 8.999970
# iteration 2800 / 3000: loss 8.999972
# iteration 2900 / 3000: loss 8.999972
# training accuracy: 0.400816
# validation accuracy: 0.379000
# lr  1e-09  reg  5000000.0
# iteration 0 / 3000: loss 7762.541805
# iteration 100 / 3000: loss 1047.812132
# iteration 200 / 3000: loss 148.181135
# iteration 300 / 3000: loss 27.647339
# iteration 400 / 3000: loss 11.498337
# iteration 500 / 3000: loss 9.334728
# iteration 600 / 3000: loss 9.044885
# iteration 700 / 3000: loss 9.006004
# iteration 800 / 3000: loss 9.000806
# iteration 900 / 3000: loss 9.000105
# iteration 1000 / 3000: loss 9.000011
# iteration 1100 / 3000: loss 8.999999
# iteration 1200 / 3000: loss 8.999997
# iteration 1300 / 3000: loss 8.999996
# iteration 1400 / 3000: loss 8.999997
# iteration 1500 / 3000: loss 8.999997
# iteration 1600 / 3000: loss 8.999996
# iteration 1700 / 3000: loss 8.999997
# iteration 1800 / 3000: loss 8.999996
# iteration 1900 / 3000: loss 8.999997
# iteration 2000 / 3000: loss 8.999996
# iteration 2100 / 3000: loss 8.999997
# iteration 2200 / 3000: loss 8.999995
# iteration 2300 / 3000: loss 8.999996
# iteration 2400 / 3000: loss 8.999996
# iteration 2500 / 3000: loss 8.999996
# iteration 2600 / 3000: loss 8.999996
# iteration 2700 / 3000: loss 8.999996
# iteration 2800 / 3000: loss 8.999996
# iteration 2900 / 3000: loss 8.999997
# training accuracy: 0.413939
# validation accuracy: 0.417000
# lr  1e-08  reg  5000000.0
# iteration 0 / 3000: loss 7331.847369
# iteration 100 / 3000: loss 9.000002
# iteration 200 / 3000: loss 8.999996
# iteration 300 / 3000: loss 8.999995
# iteration 400 / 3000: loss 8.999996
# iteration 500 / 3000: loss 8.999997
# iteration 600 / 3000: loss 8.999996
# iteration 700 / 3000: loss 8.999997
# iteration 800 / 3000: loss 8.999996
# iteration 900 / 3000: loss 8.999996
# iteration 1000 / 3000: loss 8.999997
# iteration 1100 / 3000: loss 8.999997
# iteration 1200 / 3000: loss 8.999997
# iteration 1300 / 3000: loss 8.999996
# iteration 1400 / 3000: loss 8.999996
# iteration 1500 / 3000: loss 8.999996
# iteration 1600 / 3000: loss 8.999997
# iteration 1700 / 3000: loss 8.999997
# iteration 1800 / 3000: loss 8.999997
# iteration 1900 / 3000: loss 8.999997
# iteration 2000 / 3000: loss 8.999996
# iteration 2100 / 3000: loss 8.999997
# iteration 2200 / 3000: loss 8.999997
# iteration 2300 / 3000: loss 8.999997
# iteration 2400 / 3000: loss 8.999997
# iteration 2500 / 3000: loss 8.999997
# iteration 2600 / 3000: loss 8.999997
# iteration 2700 / 3000: loss 8.999996
# iteration 2800 / 3000: loss 8.999997
# iteration 2900 / 3000: loss 8.999997
# training accuracy: 0.404837
# validation accuracy: 0.407000
# lr  1e-07  reg  5000000.0
# iteration 0 / 3000: loss 7784.656094
# iteration 100 / 3000: loss 8.999999
# iteration 200 / 3000: loss 9.000000
# iteration 300 / 3000: loss 9.000001
# iteration 400 / 3000: loss 9.000001
# iteration 500 / 3000: loss 8.999999
# iteration 600 / 3000: loss 8.999999
# iteration 700 / 3000: loss 9.000000
# iteration 800 / 3000: loss 9.000000
# iteration 900 / 3000: loss 9.000000
# iteration 1000 / 3000: loss 9.000000
# iteration 1100 / 3000: loss 9.000000
# iteration 1200 / 3000: loss 9.000000
# iteration 1300 / 3000: loss 9.000000
# iteration 1400 / 3000: loss 9.000000
# iteration 1500 / 3000: loss 9.000000
# iteration 1600 / 3000: loss 9.000000
# iteration 1700 / 3000: loss 9.000000
# iteration 1800 / 3000: loss 9.000000
# iteration 1900 / 3000: loss 9.000000
# iteration 2000 / 3000: loss 9.000000
# iteration 2100 / 3000: loss 9.000001
# iteration 2200 / 3000: loss 9.000001
# iteration 2300 / 3000: loss 9.000000
# iteration 2400 / 3000: loss 9.000000
# iteration 2500 / 3000: loss 8.999999
# iteration 2600 / 3000: loss 9.000000
# iteration 2700 / 3000: loss 9.000001
# iteration 2800 / 3000: loss 9.000000
# iteration 2900 / 3000: loss 9.000000
# training accuracy: 0.310347
# validation accuracy: 0.328000
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.086673 val accuracy: 0.102000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.120224 val accuracy: 0.112000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.413939 val accuracy: 0.417000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.096939 val accuracy: 0.096000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.413449 val accuracy: 0.401000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.404837 val accuracy: 0.407000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.418143 val accuracy: 0.419000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.400816 val accuracy: 0.379000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.310347 val accuracy: 0.328000
# best validation accuracy achieved: 0.419000

# %%
# Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.421

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$
# Not really

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

data = {
    'X_train': X_train_feats, 
    'y_train': y_train, 
    'X_val': X_val_feats, 
    'y_val': y_val, 
    'X_test': X_test_feats, 
    'y_test': y_test, 
}

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****


# learning_rates = np.logspace(-1, 0, num=6)
# regularization_strengths = np.logspace(-3, -1.5, num=6)
learning_rates = np.linspace(0.01, 0.2, num=25)
regularization_strengths = [0] #np.linspace(0., 0.01, num=5)

results = {}
best_val = -1
best_solver = None
total_combinations = len(regularization_strengths) * len(learning_rates)
current_combination = 0
for regularization_strength in regularization_strengths:
    for learning_rate in learning_rates:
        current_combination += 1
        print(f"{current_combination}/{total_combinations}: Training with learning_rate: {learning_rate} and regularization_strength {regularization_strength}")
        net = TwoLayerNet(input_dim, hidden_dim, num_classes)
        net.reg = regularization_strength
        solver = Solver(net, data,
                        update_rule='sgd',
                        optim_config={
                            'learning_rate': learning_rate,
                        },
                        lr_decay=0.95,
                        num_epochs=8, batch_size=200,
                        print_every=100)
        solver.train()
        
        validation_accuracy = solver.val_acc_history[-1]
        results[(learning_rate, regularization_strength)] = (solver.train_acc_history[-1], validation_accuracy)

        if validation_accuracy > best_val:
            best_val = validation_accuracy
            best_net = net
            best_solver = solver

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)



# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# 1/25: Training with learning_rate: 0.01 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302579
# (Epoch 0 / 8) train acc: 0.113000; val_acc: 0.110000
# (Iteration 101 / 1960) loss: 2.302419
# (Iteration 201 / 1960) loss: 2.302249
# (Epoch 1 / 8) train acc: 0.105000; val_acc: 0.088000
# (Iteration 301 / 1960) loss: 2.302197
# (Iteration 401 / 1960) loss: 2.301439
# (Epoch 2 / 8) train acc: 0.290000; val_acc: 0.273000
# (Iteration 501 / 1960) loss: 2.301367
# (Iteration 601 / 1960) loss: 2.300281
# (Iteration 701 / 1960) loss: 2.298670
# (Epoch 3 / 8) train acc: 0.276000; val_acc: 0.275000
# (Iteration 801 / 1960) loss: 2.296768
# (Iteration 901 / 1960) loss: 2.293979
# (Epoch 4 / 8) train acc: 0.277000; val_acc: 0.274000
# (Iteration 1001 / 1960) loss: 2.289199
# (Iteration 1101 / 1960) loss: 2.283901
# (Iteration 1201 / 1960) loss: 2.265927
# (Epoch 5 / 8) train acc: 0.244000; val_acc: 0.273000
# (Iteration 1301 / 1960) loss: 2.255222
# (Iteration 1401 / 1960) loss: 2.224422
# (Epoch 6 / 8) train acc: 0.259000; val_acc: 0.263000
# (Iteration 1501 / 1960) loss: 2.195366
# (Iteration 1601 / 1960) loss: 2.153648
# (Iteration 1701 / 1960) loss: 2.108041
# (Epoch 7 / 8) train acc: 0.292000; val_acc: 0.272000
# (Iteration 1801 / 1960) loss: 2.064459
# (Iteration 1901 / 1960) loss: 2.082815
# (Epoch 8 / 8) train acc: 0.295000; val_acc: 0.275000
# 2/25: Training with learning_rate: 0.017916666666666668 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302581
# (Epoch 0 / 8) train acc: 0.099000; val_acc: 0.081000
# (Iteration 101 / 1960) loss: 2.302447
# (Iteration 201 / 1960) loss: 2.301926
# (Epoch 1 / 8) train acc: 0.158000; val_acc: 0.118000
# (Iteration 301 / 1960) loss: 2.301399
# (Iteration 401 / 1960) loss: 2.300756
# (Epoch 2 / 8) train acc: 0.253000; val_acc: 0.250000
# (Iteration 501 / 1960) loss: 2.299191
# (Iteration 601 / 1960) loss: 2.295127
# (Iteration 701 / 1960) loss: 2.284601
# (Epoch 3 / 8) train acc: 0.241000; val_acc: 0.242000
# (Iteration 801 / 1960) loss: 2.277749
# (Iteration 901 / 1960) loss: 2.227691
# (Epoch 4 / 8) train acc: 0.254000; val_acc: 0.283000
# (Iteration 1001 / 1960) loss: 2.173487
# (Iteration 1101 / 1960) loss: 2.143883
# (Iteration 1201 / 1960) loss: 2.085348
# (Epoch 5 / 8) train acc: 0.265000; val_acc: 0.274000
# (Iteration 1301 / 1960) loss: 2.149786
# (Iteration 1401 / 1960) loss: 2.066001
# (Epoch 6 / 8) train acc: 0.289000; val_acc: 0.316000
# (Iteration 1501 / 1960) loss: 2.053634
# (Iteration 1601 / 1960) loss: 2.086103
# (Iteration 1701 / 1960) loss: 2.044987
# (Epoch 7 / 8) train acc: 0.355000; val_acc: 0.341000
# (Iteration 1801 / 1960) loss: 1.959726
# (Iteration 1901 / 1960) loss: 2.004118
# (Epoch 8 / 8) train acc: 0.306000; val_acc: 0.351000
# 3/25: Training with learning_rate: 0.025833333333333333 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302580
# (Epoch 0 / 8) train acc: 0.111000; val_acc: 0.119000
# (Iteration 101 / 1960) loss: 2.302253
# (Iteration 201 / 1960) loss: 2.301962
# (Epoch 1 / 8) train acc: 0.182000; val_acc: 0.186000
# (Iteration 301 / 1960) loss: 2.299353
# (Iteration 401 / 1960) loss: 2.294271
# (Epoch 2 / 8) train acc: 0.224000; val_acc: 0.230000
# (Iteration 501 / 1960) loss: 2.270914
# (Iteration 601 / 1960) loss: 2.238925
# (Iteration 701 / 1960) loss: 2.226615
# (Epoch 3 / 8) train acc: 0.225000; val_acc: 0.238000
# (Iteration 801 / 1960) loss: 2.224519
# (Iteration 901 / 1960) loss: 2.204387
# (Epoch 4 / 8) train acc: 0.251000; val_acc: 0.268000
# (Iteration 1001 / 1960) loss: 2.136072
# (Iteration 1101 / 1960) loss: 2.098054
# (Iteration 1201 / 1960) loss: 2.089836
# (Epoch 5 / 8) train acc: 0.285000; val_acc: 0.310000
# (Iteration 1301 / 1960) loss: 2.060735
# (Iteration 1401 / 1960) loss: 1.999158
# (Epoch 6 / 8) train acc: 0.342000; val_acc: 0.367000
# (Iteration 1501 / 1960) loss: 1.945285
# (Iteration 1601 / 1960) loss: 1.902143
# (Iteration 1701 / 1960) loss: 1.729715
# (Epoch 7 / 8) train acc: 0.397000; val_acc: 0.401000
# (Iteration 1801 / 1960) loss: 1.816704
# (Iteration 1901 / 1960) loss: 1.757512
# (Epoch 8 / 8) train acc: 0.392000; val_acc: 0.421000
# 4/25: Training with learning_rate: 0.03375 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302584
# (Epoch 0 / 8) train acc: 0.114000; val_acc: 0.084000
# (Iteration 101 / 1960) loss: 2.302495
# (Iteration 201 / 1960) loss: 2.302404
# (Epoch 1 / 8) train acc: 0.172000; val_acc: 0.199000
# (Iteration 301 / 1960) loss: 2.299078
# (Iteration 401 / 1960) loss: 2.290756
# (Epoch 2 / 8) train acc: 0.176000; val_acc: 0.196000
# (Iteration 501 / 1960) loss: 2.262801
# (Iteration 601 / 1960) loss: 2.134277
# (Iteration 701 / 1960) loss: 2.167146
# (Epoch 3 / 8) train acc: 0.183000; val_acc: 0.211000
# (Iteration 801 / 1960) loss: 2.120071
# (Iteration 901 / 1960) loss: 2.148712
# (Epoch 4 / 8) train acc: 0.236000; val_acc: 0.259000
# (Iteration 1001 / 1960) loss: 2.027265
# (Iteration 1101 / 1960) loss: 2.113277
# (Iteration 1201 / 1960) loss: 1.971272
# (Epoch 5 / 8) train acc: 0.326000; val_acc: 0.313000
# (Iteration 1301 / 1960) loss: 2.005010
# (Iteration 1401 / 1960) loss: 1.862572
# (Epoch 6 / 8) train acc: 0.319000; val_acc: 0.353000
# (Iteration 1501 / 1960) loss: 1.942935
# (Iteration 1601 / 1960) loss: 1.877860
# (Iteration 1701 / 1960) loss: 1.844038
# (Epoch 7 / 8) train acc: 0.322000; val_acc: 0.370000
# (Iteration 1801 / 1960) loss: 1.785604
# (Iteration 1901 / 1960) loss: 1.815364
# (Epoch 8 / 8) train acc: 0.336000; val_acc: 0.372000
# 5/25: Training with learning_rate: 0.04166666666666667 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302582
# (Epoch 0 / 8) train acc: 0.101000; val_acc: 0.119000
# (Iteration 101 / 1960) loss: 2.302700
# (Iteration 201 / 1960) loss: 2.299902
# (Epoch 1 / 8) train acc: 0.248000; val_acc: 0.248000
# (Iteration 301 / 1960) loss: 2.285406
# (Iteration 401 / 1960) loss: 2.207154
# (Epoch 2 / 8) train acc: 0.240000; val_acc: 0.247000
# (Iteration 501 / 1960) loss: 2.083194
# (Iteration 601 / 1960) loss: 2.071696
# (Iteration 701 / 1960) loss: 2.107915
# (Epoch 3 / 8) train acc: 0.284000; val_acc: 0.281000
# (Iteration 801 / 1960) loss: 2.106304
# (Iteration 901 / 1960) loss: 2.002163
# (Epoch 4 / 8) train acc: 0.289000; val_acc: 0.314000
# (Iteration 1001 / 1960) loss: 1.960334
# (Iteration 1101 / 1960) loss: 1.949072
# (Iteration 1201 / 1960) loss: 1.969097
# (Epoch 5 / 8) train acc: 0.332000; val_acc: 0.307000
# (Iteration 1301 / 1960) loss: 1.823427
# (Iteration 1401 / 1960) loss: 1.797060
# (Epoch 6 / 8) train acc: 0.321000; val_acc: 0.323000
# (Iteration 1501 / 1960) loss: 1.776176
# (Iteration 1601 / 1960) loss: 1.896360
# (Iteration 1701 / 1960) loss: 1.872048
# (Epoch 7 / 8) train acc: 0.367000; val_acc: 0.363000
# (Iteration 1801 / 1960) loss: 1.862453
# (Iteration 1901 / 1960) loss: 1.794249
# (Epoch 8 / 8) train acc: 0.354000; val_acc: 0.372000
# 6/25: Training with learning_rate: 0.04958333333333334 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302581
# (Epoch 0 / 8) train acc: 0.142000; val_acc: 0.101000
# (Iteration 101 / 1960) loss: 2.301905
# (Iteration 201 / 1960) loss: 2.288464
# (Epoch 1 / 8) train acc: 0.183000; val_acc: 0.188000
# (Iteration 301 / 1960) loss: 2.224623
# (Iteration 401 / 1960) loss: 2.157780
# (Epoch 2 / 8) train acc: 0.283000; val_acc: 0.274000
# (Iteration 501 / 1960) loss: 2.096186
# (Iteration 601 / 1960) loss: 2.008403
# (Iteration 701 / 1960) loss: 2.067614
# (Epoch 3 / 8) train acc: 0.325000; val_acc: 0.314000
# (Iteration 801 / 1960) loss: 1.885522
# (Iteration 901 / 1960) loss: 1.928619
# (Epoch 4 / 8) train acc: 0.344000; val_acc: 0.325000
# (Iteration 1001 / 1960) loss: 1.914834
# (Iteration 1101 / 1960) loss: 1.907003
# (Iteration 1201 / 1960) loss: 1.944367
# (Epoch 5 / 8) train acc: 0.354000; val_acc: 0.356000
# (Iteration 1301 / 1960) loss: 1.863209
# (Iteration 1401 / 1960) loss: 1.842998
# (Epoch 6 / 8) train acc: 0.381000; val_acc: 0.429000
# (Iteration 1501 / 1960) loss: 1.700523
# (Iteration 1601 / 1960) loss: 1.520893
# (Iteration 1701 / 1960) loss: 1.443306
# (Epoch 7 / 8) train acc: 0.479000; val_acc: 0.462000
# (Iteration 1801 / 1960) loss: 1.610936
# (Iteration 1901 / 1960) loss: 1.520570
# (Epoch 8 / 8) train acc: 0.495000; val_acc: 0.486000
# 7/25: Training with learning_rate: 0.0575 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302595
# (Epoch 0 / 8) train acc: 0.090000; val_acc: 0.089000
# (Iteration 101 / 1960) loss: 2.302167
# (Iteration 201 / 1960) loss: 2.294693
# (Epoch 1 / 8) train acc: 0.209000; val_acc: 0.239000
# (Iteration 301 / 1960) loss: 2.232208
# (Iteration 401 / 1960) loss: 2.122748
# (Epoch 2 / 8) train acc: 0.240000; val_acc: 0.257000
# (Iteration 501 / 1960) loss: 2.144350
# (Iteration 601 / 1960) loss: 2.139034
# (Iteration 701 / 1960) loss: 2.068392
# (Epoch 3 / 8) train acc: 0.270000; val_acc: 0.297000
# (Iteration 801 / 1960) loss: 1.883143
# (Iteration 901 / 1960) loss: 2.008537
# (Epoch 4 / 8) train acc: 0.307000; val_acc: 0.312000
# (Iteration 1001 / 1960) loss: 2.023976
# (Iteration 1101 / 1960) loss: 1.909067
# (Iteration 1201 / 1960) loss: 1.841470
# (Epoch 5 / 8) train acc: 0.361000; val_acc: 0.351000
# (Iteration 1301 / 1960) loss: 1.944516
# (Iteration 1401 / 1960) loss: 1.804980
# (Epoch 6 / 8) train acc: 0.387000; val_acc: 0.396000
# (Iteration 1501 / 1960) loss: 1.747314
# (Iteration 1601 / 1960) loss: 1.697473
# (Iteration 1701 / 1960) loss: 1.810858
# (Epoch 7 / 8) train acc: 0.402000; val_acc: 0.403000
# (Iteration 1801 / 1960) loss: 1.846557
# (Iteration 1901 / 1960) loss: 1.796402
# (Epoch 8 / 8) train acc: 0.417000; val_acc: 0.410000
# 8/25: Training with learning_rate: 0.06541666666666666 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302602
# (Epoch 0 / 8) train acc: 0.090000; val_acc: 0.098000
# (Iteration 101 / 1960) loss: 2.300241
# (Iteration 201 / 1960) loss: 2.290862
# (Epoch 1 / 8) train acc: 0.235000; val_acc: 0.185000
# (Iteration 301 / 1960) loss: 2.200515
# (Iteration 401 / 1960) loss: 2.044657
# (Epoch 2 / 8) train acc: 0.314000; val_acc: 0.328000
# (Iteration 501 / 1960) loss: 2.076390
# (Iteration 601 / 1960) loss: 1.930503
# (Iteration 701 / 1960) loss: 1.867279
# (Epoch 3 / 8) train acc: 0.373000; val_acc: 0.366000
# (Iteration 801 / 1960) loss: 1.875994
# (Iteration 901 / 1960) loss: 1.780875
# (Epoch 4 / 8) train acc: 0.426000; val_acc: 0.410000
# (Iteration 1001 / 1960) loss: 1.743616
# (Iteration 1101 / 1960) loss: 1.740663
# (Iteration 1201 / 1960) loss: 1.838143
# (Epoch 5 / 8) train acc: 0.433000; val_acc: 0.449000
# (Iteration 1301 / 1960) loss: 1.722066
# (Iteration 1401 / 1960) loss: 1.676537
# (Epoch 6 / 8) train acc: 0.477000; val_acc: 0.454000
# (Iteration 1501 / 1960) loss: 1.664538
# (Iteration 1601 / 1960) loss: 1.417962
# (Iteration 1701 / 1960) loss: 1.296444
# (Epoch 7 / 8) train acc: 0.520000; val_acc: 0.502000
# (Iteration 1801 / 1960) loss: 1.404726
# (Iteration 1901 / 1960) loss: 1.423245
# (Epoch 8 / 8) train acc: 0.514000; val_acc: 0.504000
# 9/25: Training with learning_rate: 0.07333333333333333 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302578
# (Epoch 0 / 8) train acc: 0.105000; val_acc: 0.113000
# (Iteration 101 / 1960) loss: 2.302124
# (Iteration 201 / 1960) loss: 2.294347
# (Epoch 1 / 8) train acc: 0.212000; val_acc: 0.206000
# (Iteration 301 / 1960) loss: 2.228992
# (Iteration 401 / 1960) loss: 2.065212
# (Epoch 2 / 8) train acc: 0.308000; val_acc: 0.268000
# (Iteration 501 / 1960) loss: 2.025239
# (Iteration 601 / 1960) loss: 1.974745
# (Iteration 701 / 1960) loss: 1.964725
# (Epoch 3 / 8) train acc: 0.317000; val_acc: 0.306000
# (Iteration 801 / 1960) loss: 1.929305
# (Iteration 901 / 1960) loss: 1.938850
# (Epoch 4 / 8) train acc: 0.311000; val_acc: 0.311000
# (Iteration 1001 / 1960) loss: 2.016735
# (Iteration 1101 / 1960) loss: 1.922960
# (Iteration 1201 / 1960) loss: 1.909471
# (Epoch 5 / 8) train acc: 0.344000; val_acc: 0.316000
# (Iteration 1301 / 1960) loss: 1.949812
# (Iteration 1401 / 1960) loss: 1.770095
# (Epoch 6 / 8) train acc: 0.350000; val_acc: 0.323000
# (Iteration 1501 / 1960) loss: 1.963979
# (Iteration 1601 / 1960) loss: 1.881387
# (Iteration 1701 / 1960) loss: 1.855467
# (Epoch 7 / 8) train acc: 0.374000; val_acc: 0.347000
# (Iteration 1801 / 1960) loss: 1.840454
# (Iteration 1901 / 1960) loss: 1.841023
# (Epoch 8 / 8) train acc: 0.387000; val_acc: 0.369000
# 10/25: Training with learning_rate: 0.08125 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302594
# (Epoch 0 / 8) train acc: 0.117000; val_acc: 0.112000
# (Iteration 101 / 1960) loss: 2.302242
# (Iteration 201 / 1960) loss: 2.301057
# (Epoch 1 / 8) train acc: 0.085000; val_acc: 0.112000
# (Iteration 301 / 1960) loss: 2.296450
# (Iteration 401 / 1960) loss: 2.269174
# (Epoch 2 / 8) train acc: 0.157000; val_acc: 0.134000
# (Iteration 501 / 1960) loss: 2.272081
# (Iteration 601 / 1960) loss: 2.220241
# (Iteration 701 / 1960) loss: 2.152467
# (Epoch 3 / 8) train acc: 0.248000; val_acc: 0.236000
# (Iteration 801 / 1960) loss: 2.054745
# (Iteration 901 / 1960) loss: 1.998259
# (Epoch 4 / 8) train acc: 0.256000; val_acc: 0.267000
# (Iteration 1001 / 1960) loss: 2.080358
# (Iteration 1101 / 1960) loss: 1.961457
# (Iteration 1201 / 1960) loss: 1.886597
# (Epoch 5 / 8) train acc: 0.357000; val_acc: 0.359000
# (Iteration 1301 / 1960) loss: 1.650093
# (Iteration 1401 / 1960) loss: 1.715420
# (Epoch 6 / 8) train acc: 0.406000; val_acc: 0.391000
# (Iteration 1501 / 1960) loss: 1.761285
# (Iteration 1601 / 1960) loss: 1.754421
# (Iteration 1701 / 1960) loss: 1.784213
# (Epoch 7 / 8) train acc: 0.448000; val_acc: 0.402000
# (Iteration 1801 / 1960) loss: 1.511119
# (Iteration 1901 / 1960) loss: 1.717383
# (Epoch 8 / 8) train acc: 0.444000; val_acc: 0.403000
# 11/25: Training with learning_rate: 0.08916666666666667 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302587
# (Epoch 0 / 8) train acc: 0.087000; val_acc: 0.108000
# (Iteration 101 / 1960) loss: 2.302884
# (Iteration 201 / 1960) loss: 2.298473
# (Epoch 1 / 8) train acc: 0.150000; val_acc: 0.198000
# (Iteration 301 / 1960) loss: 2.228855
# (Iteration 401 / 1960) loss: 2.099899
# (Epoch 2 / 8) train acc: 0.254000; val_acc: 0.267000
# (Iteration 501 / 1960) loss: 2.083417
# (Iteration 601 / 1960) loss: 2.014291
# (Iteration 701 / 1960) loss: 1.915317
# (Epoch 3 / 8) train acc: 0.354000; val_acc: 0.340000
# (Iteration 801 / 1960) loss: 1.866055
# (Iteration 901 / 1960) loss: 1.737629
# (Epoch 4 / 8) train acc: 0.433000; val_acc: 0.394000
# (Iteration 1001 / 1960) loss: 1.742558
# (Iteration 1101 / 1960) loss: 1.796708
# (Iteration 1201 / 1960) loss: 1.739489
# (Epoch 5 / 8) train acc: 0.422000; val_acc: 0.421000
# (Iteration 1301 / 1960) loss: 1.697534
# (Iteration 1401 / 1960) loss: 1.660841
# (Epoch 6 / 8) train acc: 0.449000; val_acc: 0.458000
# (Iteration 1501 / 1960) loss: 1.477352
# (Iteration 1601 / 1960) loss: 1.395309
# (Iteration 1701 / 1960) loss: 1.378368
# (Epoch 7 / 8) train acc: 0.530000; val_acc: 0.490000
# (Iteration 1801 / 1960) loss: 1.461215
# (Iteration 1901 / 1960) loss: 1.213064
# (Epoch 8 / 8) train acc: 0.544000; val_acc: 0.520000
# 12/25: Training with learning_rate: 0.09708333333333334 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302593
# (Epoch 0 / 8) train acc: 0.116000; val_acc: 0.078000
# (Iteration 101 / 1960) loss: 2.302206
# (Iteration 201 / 1960) loss: 2.300657
# (Epoch 1 / 8) train acc: 0.158000; val_acc: 0.133000
# (Iteration 301 / 1960) loss: 2.263859
# (Iteration 401 / 1960) loss: 2.217549
# (Epoch 2 / 8) train acc: 0.185000; val_acc: 0.200000
# (Iteration 501 / 1960) loss: 2.201872
# (Iteration 601 / 1960) loss: 2.176125
# (Iteration 701 / 1960) loss: 2.120024
# (Epoch 3 / 8) train acc: 0.223000; val_acc: 0.226000
# (Iteration 801 / 1960) loss: 2.167102
# (Iteration 901 / 1960) loss: 2.175512
# (Epoch 4 / 8) train acc: 0.213000; val_acc: 0.224000
# (Iteration 1001 / 1960) loss: 2.118994
# (Iteration 1101 / 1960) loss: 2.071700
# (Iteration 1201 / 1960) loss: 2.021296
# (Epoch 5 / 8) train acc: 0.219000; val_acc: 0.225000
# (Iteration 1301 / 1960) loss: 2.094254
# (Iteration 1401 / 1960) loss: 2.213189
# (Epoch 6 / 8) train acc: 0.227000; val_acc: 0.228000
# (Iteration 1501 / 1960) loss: 2.087141
# (Iteration 1601 / 1960) loss: 2.102059
# (Iteration 1701 / 1960) loss: 2.094556
# (Epoch 7 / 8) train acc: 0.249000; val_acc: 0.227000
# (Iteration 1801 / 1960) loss: 2.099930
# (Iteration 1901 / 1960) loss: 2.113199
# (Epoch 8 / 8) train acc: 0.271000; val_acc: 0.285000
# 13/25: Training with learning_rate: 0.105 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302582
# (Epoch 0 / 8) train acc: 0.105000; val_acc: 0.120000
# (Iteration 101 / 1960) loss: 2.300852
# (Iteration 201 / 1960) loss: 2.234315
# (Epoch 1 / 8) train acc: 0.208000; val_acc: 0.225000
# (Iteration 301 / 1960) loss: 2.162708
# (Iteration 401 / 1960) loss: 2.041581
# (Epoch 2 / 8) train acc: 0.308000; val_acc: 0.294000
# (Iteration 501 / 1960) loss: 2.028648
# (Iteration 601 / 1960) loss: 1.944440
# (Iteration 701 / 1960) loss: 2.130325
# (Epoch 3 / 8) train acc: 0.309000; val_acc: 0.294000
# (Iteration 801 / 1960) loss: 1.983057
# (Iteration 901 / 1960) loss: 2.005006
# (Epoch 4 / 8) train acc: 0.307000; val_acc: 0.301000
# (Iteration 1001 / 1960) loss: 1.970903
# (Iteration 1101 / 1960) loss: 1.933048
# (Iteration 1201 / 1960) loss: 2.030454
# (Epoch 5 / 8) train acc: 0.319000; val_acc: 0.304000
# (Iteration 1301 / 1960) loss: 1.889786
# (Iteration 1401 / 1960) loss: 2.115618
# (Epoch 6 / 8) train acc: 0.315000; val_acc: 0.299000
# (Iteration 1501 / 1960) loss: 2.019334
# (Iteration 1601 / 1960) loss: 2.052910
# (Iteration 1701 / 1960) loss: 2.095919
# (Epoch 7 / 8) train acc: 0.321000; val_acc: 0.308000
# (Iteration 1801 / 1960) loss: 1.903015
# (Iteration 1901 / 1960) loss: 1.807040
# (Epoch 8 / 8) train acc: 0.347000; val_acc: 0.363000
# 14/25: Training with learning_rate: 0.11291666666666667 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302587
# (Epoch 0 / 8) train acc: 0.103000; val_acc: 0.105000
# (Iteration 101 / 1960) loss: 2.301839
# (Iteration 201 / 1960) loss: 2.259494
# (Epoch 1 / 8) train acc: 0.254000; val_acc: 0.274000
# (Iteration 301 / 1960) loss: 2.029300
# (Iteration 401 / 1960) loss: 2.071003
# (Epoch 2 / 8) train acc: 0.325000; val_acc: 0.308000
# (Iteration 501 / 1960) loss: 1.858428
# (Iteration 601 / 1960) loss: 1.814937
# (Iteration 701 / 1960) loss: 1.860455
# (Epoch 3 / 8) train acc: 0.396000; val_acc: 0.366000
# (Iteration 801 / 1960) loss: 1.746143
# (Iteration 901 / 1960) loss: 1.765251
# (Epoch 4 / 8) train acc: 0.396000; val_acc: 0.368000
# (Iteration 1001 / 1960) loss: 1.837384
# (Iteration 1101 / 1960) loss: 1.620880
# (Iteration 1201 / 1960) loss: 1.548974
# (Epoch 5 / 8) train acc: 0.421000; val_acc: 0.441000
# (Iteration 1301 / 1960) loss: 1.629559
# (Iteration 1401 / 1960) loss: 1.548226
# (Epoch 6 / 8) train acc: 0.486000; val_acc: 0.467000
# (Iteration 1501 / 1960) loss: 1.555857
# (Iteration 1601 / 1960) loss: 1.403714
# (Iteration 1701 / 1960) loss: 1.401508
# (Epoch 7 / 8) train acc: 0.496000; val_acc: 0.469000
# (Iteration 1801 / 1960) loss: 1.440189
# (Iteration 1901 / 1960) loss: 1.512359
# (Epoch 8 / 8) train acc: 0.577000; val_acc: 0.515000
# 15/25: Training with learning_rate: 0.12083333333333333 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302598
# (Epoch 0 / 8) train acc: 0.101000; val_acc: 0.119000
# (Iteration 101 / 1960) loss: 2.284000
# (Iteration 201 / 1960) loss: 2.171392
# (Epoch 1 / 8) train acc: 0.312000; val_acc: 0.305000
# (Iteration 301 / 1960) loss: 1.926170
# (Iteration 401 / 1960) loss: 1.666968
# (Epoch 2 / 8) train acc: 0.393000; val_acc: 0.425000
# (Iteration 501 / 1960) loss: 1.684890
# (Iteration 601 / 1960) loss: 1.792096
# (Iteration 701 / 1960) loss: 1.565009
# (Epoch 3 / 8) train acc: 0.460000; val_acc: 0.458000
# (Iteration 801 / 1960) loss: 1.741145
# (Iteration 901 / 1960) loss: 1.671842
# (Epoch 4 / 8) train acc: 0.468000; val_acc: 0.472000
# (Iteration 1001 / 1960) loss: 1.670382
# (Iteration 1101 / 1960) loss: 1.576125
# (Iteration 1201 / 1960) loss: 1.490923
# (Epoch 5 / 8) train acc: 0.495000; val_acc: 0.468000
# (Iteration 1301 / 1960) loss: 1.622872
# (Iteration 1401 / 1960) loss: 1.532458
# (Epoch 6 / 8) train acc: 0.516000; val_acc: 0.480000
# (Iteration 1501 / 1960) loss: 1.548322
# (Iteration 1601 / 1960) loss: 1.532614
# (Iteration 1701 / 1960) loss: 1.491060
# (Epoch 7 / 8) train acc: 0.525000; val_acc: 0.479000
# (Iteration 1801 / 1960) loss: 1.509078
# (Iteration 1901 / 1960) loss: 1.573046
# (Epoch 8 / 8) train acc: 0.536000; val_acc: 0.486000
# 16/25: Training with learning_rate: 0.12875 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302600
# (Epoch 0 / 8) train acc: 0.110000; val_acc: 0.112000
# (Iteration 101 / 1960) loss: 2.297908
# (Iteration 201 / 1960) loss: 2.153452
# (Epoch 1 / 8) train acc: 0.278000; val_acc: 0.282000
# (Iteration 301 / 1960) loss: 1.958092
# (Iteration 401 / 1960) loss: 1.972631
# (Epoch 2 / 8) train acc: 0.309000; val_acc: 0.333000
# (Iteration 501 / 1960) loss: 1.948740
# (Iteration 601 / 1960) loss: 1.878299
# (Iteration 701 / 1960) loss: 1.876575
# (Epoch 3 / 8) train acc: 0.385000; val_acc: 0.381000
# (Iteration 801 / 1960) loss: 1.850066
# (Iteration 901 / 1960) loss: 1.650089
# (Epoch 4 / 8) train acc: 0.413000; val_acc: 0.426000
# (Iteration 1001 / 1960) loss: 1.555524
# (Iteration 1101 / 1960) loss: 1.641745
# (Iteration 1201 / 1960) loss: 1.496507
# (Epoch 5 / 8) train acc: 0.506000; val_acc: 0.492000
# (Iteration 1301 / 1960) loss: 1.589761
# (Iteration 1401 / 1960) loss: 1.488747
# (Epoch 6 / 8) train acc: 0.517000; val_acc: 0.494000
# (Iteration 1501 / 1960) loss: 1.500616
# (Iteration 1601 / 1960) loss: 1.234497
# (Iteration 1701 / 1960) loss: 1.152784
# (Epoch 7 / 8) train acc: 0.511000; val_acc: 0.519000
# (Iteration 1801 / 1960) loss: 1.380041
# (Iteration 1901 / 1960) loss: 1.245822
# (Epoch 8 / 8) train acc: 0.579000; val_acc: 0.531000
# 17/25: Training with learning_rate: 0.1366666666666667 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302600
# (Epoch 0 / 8) train acc: 0.117000; val_acc: 0.113000
# (Iteration 101 / 1960) loss: 2.252129
# (Iteration 201 / 1960) loss: 2.033145
# (Epoch 1 / 8) train acc: 0.232000; val_acc: 0.246000
# (Iteration 301 / 1960) loss: 1.843486
# (Iteration 401 / 1960) loss: 2.001396
# (Epoch 2 / 8) train acc: 0.268000; val_acc: 0.293000
# (Iteration 501 / 1960) loss: 1.900174
# (Iteration 601 / 1960) loss: 1.840267
# (Iteration 701 / 1960) loss: 1.954345
# (Epoch 3 / 8) train acc: 0.265000; val_acc: 0.289000
# (Iteration 801 / 1960) loss: 1.871290
# (Iteration 901 / 1960) loss: 1.803760
# (Epoch 4 / 8) train acc: 0.276000; val_acc: 0.291000
# (Iteration 1001 / 1960) loss: 1.936762
# (Iteration 1101 / 1960) loss: 1.844500
# (Iteration 1201 / 1960) loss: 1.941079
# (Epoch 5 / 8) train acc: 0.377000; val_acc: 0.391000
# (Iteration 1301 / 1960) loss: 1.719363
# (Iteration 1401 / 1960) loss: 1.809042
# (Epoch 6 / 8) train acc: 0.400000; val_acc: 0.410000
# (Iteration 1501 / 1960) loss: 1.771691
# (Iteration 1601 / 1960) loss: 1.640572
# (Iteration 1701 / 1960) loss: 1.456295
# (Epoch 7 / 8) train acc: 0.487000; val_acc: 0.476000
# (Iteration 1801 / 1960) loss: 1.470957
# (Iteration 1901 / 1960) loss: 1.484855
# (Epoch 8 / 8) train acc: 0.497000; val_acc: 0.488000
# 18/25: Training with learning_rate: 0.14458333333333334 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302574
# (Epoch 0 / 8) train acc: 0.109000; val_acc: 0.102000
# (Iteration 101 / 1960) loss: 2.299395
# (Iteration 201 / 1960) loss: 2.235720
# (Epoch 1 / 8) train acc: 0.164000; val_acc: 0.161000
# (Iteration 301 / 1960) loss: 2.216458
# (Iteration 401 / 1960) loss: 2.093523
# (Epoch 2 / 8) train acc: 0.204000; val_acc: 0.220000
# (Iteration 501 / 1960) loss: 2.044815
# (Iteration 601 / 1960) loss: 2.059820
# (Iteration 701 / 1960) loss: 2.046555
# (Epoch 3 / 8) train acc: 0.274000; val_acc: 0.298000
# (Iteration 801 / 1960) loss: 1.831558
# (Iteration 901 / 1960) loss: 1.762513
# (Epoch 4 / 8) train acc: 0.333000; val_acc: 0.357000
# (Iteration 1001 / 1960) loss: 1.796351
# (Iteration 1101 / 1960) loss: 1.844316
# (Iteration 1201 / 1960) loss: 1.817543
# (Epoch 5 / 8) train acc: 0.390000; val_acc: 0.429000
# (Iteration 1301 / 1960) loss: 1.747589
# (Iteration 1401 / 1960) loss: 1.668948
# (Epoch 6 / 8) train acc: 0.469000; val_acc: 0.439000
# (Iteration 1501 / 1960) loss: 1.586289
# (Iteration 1601 / 1960) loss: 1.473827
# (Iteration 1701 / 1960) loss: 1.671778
# (Epoch 7 / 8) train acc: 0.442000; val_acc: 0.450000
# (Iteration 1801 / 1960) loss: 1.480119
# (Iteration 1901 / 1960) loss: 1.510948
# (Epoch 8 / 8) train acc: 0.494000; val_acc: 0.450000
# 19/25: Training with learning_rate: 0.15250000000000002 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302592
# (Epoch 0 / 8) train acc: 0.102000; val_acc: 0.119000
# (Iteration 101 / 1960) loss: 2.238814
# (Iteration 201 / 1960) loss: 2.060628
# (Epoch 1 / 8) train acc: 0.258000; val_acc: 0.269000
# (Iteration 301 / 1960) loss: 2.074932
# (Iteration 401 / 1960) loss: 1.967770
# (Epoch 2 / 8) train acc: 0.305000; val_acc: 0.332000
# (Iteration 501 / 1960) loss: 2.006337
# (Iteration 601 / 1960) loss: 1.998853
# (Iteration 701 / 1960) loss: 1.966579
# (Epoch 3 / 8) train acc: 0.330000; val_acc: 0.337000
# (Iteration 801 / 1960) loss: 1.923689
# (Iteration 901 / 1960) loss: 1.951453
# (Epoch 4 / 8) train acc: 0.305000; val_acc: 0.326000
# (Iteration 1001 / 1960) loss: 2.049831
# (Iteration 1101 / 1960) loss: 2.030928
# (Iteration 1201 / 1960) loss: 1.992583
# (Epoch 5 / 8) train acc: 0.306000; val_acc: 0.315000
# (Iteration 1301 / 1960) loss: 1.974900
# (Iteration 1401 / 1960) loss: 1.866756
# (Epoch 6 / 8) train acc: 0.360000; val_acc: 0.374000
# (Iteration 1501 / 1960) loss: 1.903927
# (Iteration 1601 / 1960) loss: 1.871978
# (Iteration 1701 / 1960) loss: 1.702086
# (Epoch 7 / 8) train acc: 0.418000; val_acc: 0.367000
# (Iteration 1801 / 1960) loss: 1.800748
# (Iteration 1901 / 1960) loss: 1.754221
# (Epoch 8 / 8) train acc: 0.422000; val_acc: 0.386000
# 20/25: Training with learning_rate: 0.16041666666666668 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302593
# (Epoch 0 / 8) train acc: 0.102000; val_acc: 0.087000
# (Iteration 101 / 1960) loss: 2.272176
# (Iteration 201 / 1960) loss: 2.187475
# (Epoch 1 / 8) train acc: 0.230000; val_acc: 0.226000
# (Iteration 301 / 1960) loss: 2.163421
# (Iteration 401 / 1960) loss: 2.154959
# (Epoch 2 / 8) train acc: 0.284000; val_acc: 0.266000
# (Iteration 501 / 1960) loss: 2.011137
# (Iteration 601 / 1960) loss: 2.004724
# (Iteration 701 / 1960) loss: 1.999528
# (Epoch 3 / 8) train acc: 0.295000; val_acc: 0.292000
# (Iteration 801 / 1960) loss: 2.123058
# (Iteration 901 / 1960) loss: 2.098347
# (Epoch 4 / 8) train acc: 0.295000; val_acc: 0.295000
# (Iteration 1001 / 1960) loss: 1.931196
# (Iteration 1101 / 1960) loss: 2.078572
# (Iteration 1201 / 1960) loss: 1.973143
# (Epoch 5 / 8) train acc: 0.323000; val_acc: 0.296000
# (Iteration 1301 / 1960) loss: 1.855952
# (Iteration 1401 / 1960) loss: 2.003099
# (Epoch 6 / 8) train acc: 0.395000; val_acc: 0.350000
# (Iteration 1501 / 1960) loss: 1.811902
# (Iteration 1601 / 1960) loss: 1.874656
# (Iteration 1701 / 1960) loss: 1.716931
# (Epoch 7 / 8) train acc: 0.441000; val_acc: 0.396000
# (Iteration 1801 / 1960) loss: 1.695802
# (Iteration 1901 / 1960) loss: 1.577571
# (Epoch 8 / 8) train acc: 0.455000; val_acc: 0.454000
# 21/25: Training with learning_rate: 0.16833333333333336 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302593
# (Epoch 0 / 8) train acc: 0.110000; val_acc: 0.078000
# (Iteration 101 / 1960) loss: 2.297733
# (Iteration 201 / 1960) loss: 2.246602
# (Epoch 1 / 8) train acc: 0.170000; val_acc: 0.168000
# (Iteration 301 / 1960) loss: 2.258476
# (Iteration 401 / 1960) loss: 2.184984
# (Epoch 2 / 8) train acc: 0.219000; val_acc: 0.177000
# (Iteration 501 / 1960) loss: 2.173161
# (Iteration 601 / 1960) loss: 2.182504
# (Iteration 701 / 1960) loss: 2.042912
# (Epoch 3 / 8) train acc: 0.277000; val_acc: 0.278000
# (Iteration 801 / 1960) loss: 1.938947
# (Iteration 901 / 1960) loss: 1.949293
# (Epoch 4 / 8) train acc: 0.358000; val_acc: 0.370000
# (Iteration 1001 / 1960) loss: 1.831543
# (Iteration 1101 / 1960) loss: 1.748335
# (Iteration 1201 / 1960) loss: 1.709919
# (Epoch 5 / 8) train acc: 0.393000; val_acc: 0.383000
# (Iteration 1301 / 1960) loss: 1.842587
# (Iteration 1401 / 1960) loss: 1.797713
# (Epoch 6 / 8) train acc: 0.415000; val_acc: 0.378000
# (Iteration 1501 / 1960) loss: 1.799812
# (Iteration 1601 / 1960) loss: 1.615071
# (Iteration 1701 / 1960) loss: 1.770000
# (Epoch 7 / 8) train acc: 0.402000; val_acc: 0.389000
# (Iteration 1801 / 1960) loss: 1.869174
# (Iteration 1901 / 1960) loss: 1.884989
# (Epoch 8 / 8) train acc: 0.445000; val_acc: 0.382000
# 22/25: Training with learning_rate: 0.17625000000000002 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302583
# (Epoch 0 / 8) train acc: 0.086000; val_acc: 0.112000
# (Iteration 101 / 1960) loss: 2.301652
# (Iteration 201 / 1960) loss: 2.280035
# (Epoch 1 / 8) train acc: 0.166000; val_acc: 0.158000
# (Iteration 301 / 1960) loss: 2.233319
# (Iteration 401 / 1960) loss: 2.191131
# (Epoch 2 / 8) train acc: 0.162000; val_acc: 0.161000
# (Iteration 501 / 1960) loss: 2.225380
# (Iteration 601 / 1960) loss: 2.209588
# (Iteration 701 / 1960) loss: 2.170058
# (Epoch 3 / 8) train acc: 0.249000; val_acc: 0.261000
# (Iteration 801 / 1960) loss: 2.132338
# (Iteration 901 / 1960) loss: 2.070098
# (Epoch 4 / 8) train acc: 0.273000; val_acc: 0.293000
# (Iteration 1001 / 1960) loss: 2.047303
# (Iteration 1101 / 1960) loss: 1.970080
# (Iteration 1201 / 1960) loss: 2.073455
# (Epoch 5 / 8) train acc: 0.285000; val_acc: 0.291000
# (Iteration 1301 / 1960) loss: 2.155003
# (Iteration 1401 / 1960) loss: 2.052530
# (Epoch 6 / 8) train acc: 0.279000; val_acc: 0.294000
# (Iteration 1501 / 1960) loss: 2.050145
# (Iteration 1601 / 1960) loss: 2.072101
# (Iteration 1701 / 1960) loss: 2.100098
# (Epoch 7 / 8) train acc: 0.308000; val_acc: 0.304000
# (Iteration 1801 / 1960) loss: 2.101883
# (Iteration 1901 / 1960) loss: 2.175470
# (Epoch 8 / 8) train acc: 0.288000; val_acc: 0.300000
# 23/25: Training with learning_rate: 0.1841666666666667 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302579
# (Epoch 0 / 8) train acc: 0.125000; val_acc: 0.103000
# (Iteration 101 / 1960) loss: 2.235454
# (Iteration 201 / 1960) loss: 2.066747
# (Epoch 1 / 8) train acc: 0.287000; val_acc: 0.280000
# (Iteration 301 / 1960) loss: 2.060262
# (Iteration 401 / 1960) loss: 1.908092
# (Epoch 2 / 8) train acc: 0.320000; val_acc: 0.308000
# (Iteration 501 / 1960) loss: 1.899522
# (Iteration 601 / 1960) loss: 2.012737
# (Iteration 701 / 1960) loss: 1.996004
# (Epoch 3 / 8) train acc: 0.329000; val_acc: 0.322000
# (Iteration 801 / 1960) loss: 1.801636
# (Iteration 901 / 1960) loss: 1.767582
# (Epoch 4 / 8) train acc: 0.433000; val_acc: 0.411000
# (Iteration 1001 / 1960) loss: 1.696005
# (Iteration 1101 / 1960) loss: 1.649285
# (Iteration 1201 / 1960) loss: 1.590004
# (Epoch 5 / 8) train acc: 0.416000; val_acc: 0.418000
# (Iteration 1301 / 1960) loss: 1.590635
# (Iteration 1401 / 1960) loss: 1.677962
# (Epoch 6 / 8) train acc: 0.469000; val_acc: 0.430000
# (Iteration 1501 / 1960) loss: 1.517213
# (Iteration 1601 / 1960) loss: 1.508284
# (Iteration 1701 / 1960) loss: 1.530825
# (Epoch 7 / 8) train acc: 0.481000; val_acc: 0.440000
# (Iteration 1801 / 1960) loss: 1.499665
# (Iteration 1901 / 1960) loss: 1.559817
# (Epoch 8 / 8) train acc: 0.496000; val_acc: 0.437000
# 24/25: Training with learning_rate: 0.19208333333333336 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302588
# (Epoch 0 / 8) train acc: 0.114000; val_acc: 0.113000
# (Iteration 101 / 1960) loss: 2.233525
# (Iteration 201 / 1960) loss: 2.181904
# (Epoch 1 / 8) train acc: 0.145000; val_acc: 0.147000
# (Iteration 301 / 1960) loss: 2.122927
# (Iteration 401 / 1960) loss: 2.078936
# (Epoch 2 / 8) train acc: 0.150000; val_acc: 0.148000
# (Iteration 501 / 1960) loss: 2.176601
# (Iteration 601 / 1960) loss: 2.049514
# (Iteration 701 / 1960) loss: 2.005331
# (Epoch 3 / 8) train acc: 0.212000; val_acc: 0.199000
# (Iteration 801 / 1960) loss: 2.033078
# (Iteration 901 / 1960) loss: 2.052624
# (Epoch 4 / 8) train acc: 0.202000; val_acc: 0.194000
# (Iteration 1001 / 1960) loss: 1.968500
# (Iteration 1101 / 1960) loss: 2.061487
# (Iteration 1201 / 1960) loss: 2.047148
# (Epoch 5 / 8) train acc: 0.204000; val_acc: 0.197000
# (Iteration 1301 / 1960) loss: 2.037237
# (Iteration 1401 / 1960) loss: 2.167329
# (Epoch 6 / 8) train acc: 0.206000; val_acc: 0.205000
# (Iteration 1501 / 1960) loss: 2.038670
# (Iteration 1601 / 1960) loss: 2.009311
# (Iteration 1701 / 1960) loss: 2.085179
# (Epoch 7 / 8) train acc: 0.220000; val_acc: 0.200000
# (Iteration 1801 / 1960) loss: 2.057801
# (Iteration 1901 / 1960) loss: 2.050319
# (Epoch 8 / 8) train acc: 0.223000; val_acc: 0.198000
# 25/25: Training with learning_rate: 0.2 and regularization_strength 0
# (Iteration 1 / 1960) loss: 2.302585
# (Epoch 0 / 8) train acc: 0.109000; val_acc: 0.114000
# (Iteration 101 / 1960) loss: 2.248134
# (Iteration 201 / 1960) loss: 2.282623
# (Epoch 1 / 8) train acc: 0.177000; val_acc: 0.175000
# (Iteration 301 / 1960) loss: 2.203063
# (Iteration 401 / 1960) loss: 2.130818
# (Epoch 2 / 8) train acc: 0.282000; val_acc: 0.307000
# (Iteration 501 / 1960) loss: 2.104616
# (Iteration 601 / 1960) loss: 2.126026
# (Iteration 701 / 1960) loss: 2.145466
# (Epoch 3 / 8) train acc: 0.319000; val_acc: 0.318000
# (Iteration 801 / 1960) loss: 1.801548
# (Iteration 901 / 1960) loss: 1.954510
# (Epoch 4 / 8) train acc: 0.357000; val_acc: 0.391000
# (Iteration 1001 / 1960) loss: 1.812057
# (Iteration 1101 / 1960) loss: 1.916967
# (Iteration 1201 / 1960) loss: 1.765774
# (Epoch 5 / 8) train acc: 0.371000; val_acc: 0.404000
# (Iteration 1301 / 1960) loss: 1.734452
# (Iteration 1401 / 1960) loss: 1.780112
# (Epoch 6 / 8) train acc: 0.415000; val_acc: 0.407000
# (Iteration 1501 / 1960) loss: 1.816140
# (Iteration 1601 / 1960) loss: 1.689534
# (Iteration 1701 / 1960) loss: 1.556116
# (Epoch 7 / 8) train acc: 0.490000; val_acc: 0.499000
# (Iteration 1801 / 1960) loss: 1.586363
# (Iteration 1901 / 1960) loss: 1.639568
# (Epoch 8 / 8) train acc: 0.516000; val_acc: 0.527000
# lr 1.000000e-02 reg 0.000000e+00 train accuracy: 0.295000 val accuracy: 0.275000
# lr 1.791667e-02 reg 0.000000e+00 train accuracy: 0.306000 val accuracy: 0.351000
# lr 2.583333e-02 reg 0.000000e+00 train accuracy: 0.392000 val accuracy: 0.421000
# lr 3.375000e-02 reg 0.000000e+00 train accuracy: 0.336000 val accuracy: 0.372000
# lr 4.166667e-02 reg 0.000000e+00 train accuracy: 0.354000 val accuracy: 0.372000
# lr 4.958333e-02 reg 0.000000e+00 train accuracy: 0.495000 val accuracy: 0.486000
# lr 5.750000e-02 reg 0.000000e+00 train accuracy: 0.417000 val accuracy: 0.410000
# lr 6.541667e-02 reg 0.000000e+00 train accuracy: 0.514000 val accuracy: 0.504000
# lr 7.333333e-02 reg 0.000000e+00 train accuracy: 0.387000 val accuracy: 0.369000
# lr 8.125000e-02 reg 0.000000e+00 train accuracy: 0.444000 val accuracy: 0.403000
# lr 8.916667e-02 reg 0.000000e+00 train accuracy: 0.544000 val accuracy: 0.520000
# lr 9.708333e-02 reg 0.000000e+00 train accuracy: 0.271000 val accuracy: 0.285000
# lr 1.050000e-01 reg 0.000000e+00 train accuracy: 0.347000 val accuracy: 0.363000
# lr 1.129167e-01 reg 0.000000e+00 train accuracy: 0.577000 val accuracy: 0.515000
# lr 1.208333e-01 reg 0.000000e+00 train accuracy: 0.536000 val accuracy: 0.486000
# lr 1.287500e-01 reg 0.000000e+00 train accuracy: 0.579000 val accuracy: 0.531000
# lr 1.366667e-01 reg 0.000000e+00 train accuracy: 0.497000 val accuracy: 0.488000
# lr 1.445833e-01 reg 0.000000e+00 train accuracy: 0.494000 val accuracy: 0.450000
# lr 1.525000e-01 reg 0.000000e+00 train accuracy: 0.422000 val accuracy: 0.386000
# lr 1.604167e-01 reg 0.000000e+00 train accuracy: 0.455000 val accuracy: 0.454000
# lr 1.683333e-01 reg 0.000000e+00 train accuracy: 0.445000 val accuracy: 0.382000
# lr 1.762500e-01 reg 0.000000e+00 train accuracy: 0.288000 val accuracy: 0.300000
# lr 1.841667e-01 reg 0.000000e+00 train accuracy: 0.496000 val accuracy: 0.437000
# lr 1.920833e-01 reg 0.000000e+00 train accuracy: 0.223000 val accuracy: 0.198000
# lr 2.000000e-01 reg 0.000000e+00 train accuracy: 0.516000 val accuracy: 0.527000
# best validation accuracy achieved during cross-validation: 0.531000

# %%
# Visualize the cross-validation results
import math
import pdb

# pdb.set_trace()

# x_scatter = [math.log10(x[0]) for x in results]
# y_scatter = [math.log10(x[1]) for x in results]

# # plot training accuracy
# marker_size = 100
# colors = [results[x][0] for x in results]
# plt.subplot(2, 1, 1)
# plt.tight_layout(pad=3)
# plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
# plt.colorbar()
# plt.xlabel('log learning rate')
# plt.ylabel('log regularization strength')
# plt.title('CIFAR-10 training accuracy')

# # plot validation accuracy
# colors = [results[x][1] for x in results] # default size of markers is 20
# plt.subplot(2, 1, 2)
# plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
# plt.colorbar()
# plt.xlabel('log learning rate')
# plt.ylabel('log regularization strength')
# plt.title('CIFAR-10 validation accuracy')
# plt.show()


x_scatter = [(x[0]) for x in results]
y_scatter = [(x[1]) for x in results]
# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.tight_layout(pad=3)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('learning rate')
plt.ylabel('regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.xlabel('learning rate')
plt.ylabel('regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.53
